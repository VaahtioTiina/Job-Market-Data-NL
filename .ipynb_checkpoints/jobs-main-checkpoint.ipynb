# %% [markdown]
# # Job Market for Data Professionals in the Netherlands - Exploratory Analysis
#
# This is the third and lart part of the project conducted to analyze the job market for data professionals in the Netherlands.
#
# This notebook caries out a exploratory as well as statistical analysis of the job-listings data.

# %%
# Import basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Import map-related libraries
import requests
import folium
import json
from folium.plugins import FastMarkerCluster

# Import statistics libraries
import scipy.stats
from scipy.stats import ttest_1samp
import statsmodels.api as sm

# Import SQL libraries
import pymysql 
from sqlalchemy import create_engine  
import pandas as pd


# import Worldcloud
from wordcloud import WordCloud
from PIL import Image

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
engine = create_engine('mysql+pymysql://root:xxxx@localhost:3306/data_jobs_nl')

# %%
sql_query = 'SELECT * FROM jobs_last_30;'
jobs = pd.read_sql_query(sql_query, engine)

# %%
jobs = pd.read_csv('jobs_cleaned_final.csv')

# %%
jobs.head()
# Out:
#                                    Title    Location           Company  \
# 0     CUSTOMS ADVISOR DATA ANALIST BREDA       Breda               DHL
# 1  Specialist Business Intelligence (BI)   Rotterdam            Milgro
# 2          Business Intelligence Analist  Nieuwegein      Fysioholland
# 3                  Data analist parttime   Amsterdam           Work-on
# 4                           Data Analist     Utrecht  Visser van Baars
#
#                       Salary          Since                      Industry  \
# 0  €2.900 - €3.500 per maand  Net geplaatst    Transport en vrachtvervoer
# 1                        NaN  Net geplaatst                           NaN
# 2                        NaN  Net geplaatst                           NaN
# 3          €11 - €13 per uur  Net geplaatst  Human resources en personeel
# 4  €4.000 - €5.200 per maand  Net geplaatst                           NaN
#
#       Company size                              Title Grouped  Min Salary  \
# ...

# %%
jobs.shape
# Out:
# (438, 18)

# %%
jobs.info
# Out:
# <bound method DataFrame.info of                                                  Title               Location  \
# 0                   CUSTOMS ADVISOR DATA ANALIST BREDA                  Breda
# 1                Specialist Business Intelligence (BI)              Rotterdam
# 2                        Business Intelligence Analist             Nieuwegein
# 3                                Data analist parttime              Amsterdam
# 4                                         Data Analist                Utrecht
# ..                                                 ...                    ...
# 433                   Business Intelligence Consultant               Den Haag
# 434  Consultant Data & Analytics (Data analist, rep...      Amsterdam Centrum
# 435                    senior engineer Big Data System  Driebergen-Rijsenburg
# 436                Data analist in accountancy branche                Wijchen
# 437                  Junior data analist (accountancy)                 Arnhem
#
# ...

# %% [markdown]
# In this analysis we will only concentrate on the jobs posted in the last 30 days

# %%
jobs = jobs[jobs['Posted_days'] < 30]
print(jobs.shape)
# Out:
# (360, 18)

# %% [markdown]
# ### Which jobs are available and where?

# %%
plt.rcParams["figure.figsize"] = [10, 5]

jobs['Title Grouped'].value_counts().sort_values().plot.barh()
plt.show()

# %%
titles_wc = WordCloud(
    background_color='black',
    max_words=2000,
    collocations=True
)

#generate the word cloud
titles_wc.generate(' '.join(jobs['Title']))

# display the cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(titles_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Disctionary of titles 

title_freq = {}

for title in jobs['Title']:
    if title not in title_freq:
        title_freq[title] = 1
    else:
        title_freq[title] += 1
        
title_freq
# Out:
# {'CUSTOMS ADVISOR DATA ANALIST BREDA': 1,
#  'Specialist Business Intelligence (BI)': 1,
#  'Business Intelligence Analist': 3,
#  'Data analist parttime': 1,
#  'Data Analist': 12,
#  'Business Analist – Projectleider': 1,
#  'Data Visualisatie Expert': 1,
#  'Senior BI Consultant voor Logistiek Pakketten': 1,
#  'Data Engineering Consultant': 1,
#  'Product Owner Dataservices': 3,
#  'Slimme junior data-analist/ programmeur': 1,
#  'Internship Business Intelligence': 1,
#  'Voice data-engineer': 1,
#  'Data Engineer': 17,
#  'System & Data Engineer': 2,
#  'Business Analist / Projectleider Utrecht': 1,
#  'Data Analyst Sales & Marketing Internship / Graduate': 1,
#  'Postdoc Humanizing Acoustic Data for Wellbeing': 1,
#  'HBO Meewerkstage Data Science': 1,
#  'Content Marketeer - GoDataDriven': 1,
#  'Chapter Lead Data Engineering - Financial Crime & RegTech': 1,
#  'Data Scientist 0,8 fte': 1,
#  'Business Analist Forecasting': 1,
#  'Data Science Engineer': 1,
# ...

# %%
# Titles WordCloud
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=title_freq)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Jobs posted in the last 30 days
plt.rcParams["figure.figsize"] = [15, 5]

role_colors = {'Data Analyst': 'blue', 'Data Engineer':'orange', 'Data Scientist':'red', 'Business Analyst':'green', 'Business Intelligene Consultant/Engineer':'purple', 'Translator':'pink', 'Other':'brown'}


title = jobs.groupby(['Title Grouped', 'Date_posted'])[['Company']].count().reset_index()
title.rename(columns={'Company': 'Job Count'}, inplace=True)

pivot_titles = title.pivot(index='Date_posted', columns='Title Grouped', values='Job Count')


pivot_titles.plot.bar(stacked=True)

plt.legend(bbox_to_anchor=(0, 0.9, 1., .102), loc='upper left',
           ncol=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Did we see upwards trend? Increasing number of posts per day in the last 30 Days?

# %%
posted_trend = jobs.groupby('Posted_days')[['Title']].count().reset_index()
posted_trend.rename(columns={'Title': 'Job Count'}, inplace=True)
sns.regplot(-posted_trend['Posted_days'], posted_trend['Job Count'], fit_reg=True)
print(-posted_trend.corr())
# Out:
#              Posted_days  Job Count
# Posted_days    -1.000000   0.537267
# Job Count       0.537267  -1.000000

# %% [markdown]
# While there is an increase and positive correlation on the days posted and the count of job listings. One of the explanations is that the job market is starting to freshen up after slow-down of covid-19. However, it may also just be about the posting behaviour of companies. Maybe after certain amount of days the companies delete and re-post their job listings.

# %% [markdown]
# ## Locations

# %%
jobs['Location Grouped'].value_counts().head(15)
# Out:
# Amsterdam     93
# Utrecht       54
# Rotterdam     24
# Den Haag      18
# Eindhoven     13
# Amersfoort    11
# Nederland     10
# Den Bosch      9
# Diemen         8
# Delft          6
# Arnhem         5
# Hoofddorp      5
# Zwolle         4
# Nijmegen       4
# Maastricht     4
# Name: Location Grouped, dtype: int64

# %%
top_locs = jobs['Location Grouped'].value_counts().head(5).index

# %%
title_loc = jobs.groupby(['Location Grouped', 'Title Grouped'])[['Company']].count()
title_loc.rename(columns={'Company': 'Job Count'}, inplace=True)

title_loc.head()

title_loc['loc_count'] = title_loc.groupby('Location Grouped')['Job Count'].transform(sum)
title_loc =title_loc.sort_values(['loc_count','Job Count'], ascending=[False, False]).drop('loc_count', axis=1)

title_loc.head(60)
# Out:
#                                                             Job Count
# Location Grouped Title Grouped
# Amsterdam        Data Engineer                                     28
#                  Data Analyst                                      18
#                  Data Scientist                                    17
#                  Business Intelligence Consultant/Engineer         11
#                  Other                                             10
#                  Business Analyst                                   9
# Utrecht          Business Analyst                                  11
#                  Data Scientist                                    10
#                  Data Analyst                                       9
#                  Business Intelligence Consultant/Engineer          8
#                  Other                                              8
#                  Data Engineer                                      7
# ...

# %%
# url = 'https://www.webuildinternet.com/articles/2015-07-19-geojson-data-of-the-netherlands/townships.geojson'

# nl_geo = requests.get(url)
# nl_geo = nl_geo.json()

with open('nlcitiesgeo.json') as json_file:
    nl_geo = json.load(json_file)

# %%
nl_map = folium.Map(location=[52.21158, 5.600489], zoom_start = 7,  tiles='Mapbox Bright')

# %%
# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
title_geo = pd.DataFrame(jobs['Location Grouped'].value_counts()).reset_index()


choropleth = folium.Choropleth(
    geo_data=nl_geo,
    data=title_geo,
    columns=['index', 'Location Grouped'],
    key_on='feature.properties.name',
    fill_color='Blues', 
    fill_opacity=0.7, 
    line_opacity=0.5,
    nan_fill_color='grey',
    nan_fill_opacity=0.2,
    legend_name='Jos for Data Professionals in the Netherlands'
).add_to(nl_map)


# add labels indicating the name of the community
style_function = "font-size: 15px; font-weight: bold"
choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'], style=style_function, labels=False))



# create a layer control
folium.LayerControl().add_to(nl_map)

# display map
nl_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Industries

# %%
# Find industries for top 15 
jobs['Industry'].value_counts()
# Out:
# Human resources en personeel                        31
# Banken en financiële dienstverlening                26
# Consultancy en zakelijke dienstverlening            19
# Internet en software                                15
# Overheid                                            11
# Detailhandel                                         7
# Transport en vrachtvervoer                           6
# Voedingsmiddelen en dranken                          4
# Gezondheidszorg                                      4
# Consumentengoederen en dienstverlening               4
# Energie en nutsbedrijven                             3
# Verzekering                                          3
# Telecommunicatie                                     2
# Farmaceutica                                         2
# Computers en elektronica                             2
# Restaurants, reizen en vrije tijd                    2
# Onroerend goed                                       1
# ...

# %% [markdown]
# Are specific industries currently hiring for specific roles?

# %%
ind_title = jobs.groupby(['Industry', 'Title Grouped'])[['Title']].count()
ind_title.rename(columns={'Title': 'Job Count'}, inplace=True)


ind_title['loc_count'] = ind_title.groupby('Industry')['Job Count'].transform(sum)
ind_title = ind_title.sort_values(['loc_count','Job Count'], ascending=[False, False]).drop('loc_count', axis=1)

ind_title.head(60)
# Out:
#                                                                                     Job Count
# Industry                                 Title Grouped
# Human resources en personeel             Data Analyst                                      11
#                                          Data Engineer                                      8
#                                          Other                                              5
#                                          Business Intelligence Consultant/Engineer          4
#                                          Data Scientist                                     2
#                                          Business Analyst                                   1
# Banken en financiële dienstverlening     Data Analyst                                       8
#                                          Business Analyst                                   7
# ...

# %% [markdown]
# ### Companies

# %%
len(jobs.Company.unique())
# Out:
# 265

# %%
jobs.Company.value_counts().head(15)
# Out:
# ING                       7
# Darwin Recruitment        6
# True Legends              6
# iSense                    5
# ilionx                    5
# Rabobank                  5
# Digital Decisions         4
# Hot ITem                  4
# TU Delft                  4
# ABN AMRO Bank             4
# De Staffing Groep         4
# CarNext.com               3
# Independent Recruiters    3
# Visser & Van Baars        3
# Sogeti                    3
# Name: Company, dtype: int64

# %%
jobs[jobs['Industry'].isnull()].groupby(['Company', 'Location Grouped']).count().sort_values(by='Title', ascending=False).head(60)
# Out:
#                                               Title  Location  Salary  Since  \
# Company                     Location Grouped
# Darwin Recruitment          Amsterdam             4         4       3      4
# De Staffing Groep           Utrecht               4         4       0      4
# Hot ITem                    Amsterdam             4         4       0      4
# TU Delft                    Delft                 4         4       4      4
# Digital Decisions           Utrecht               4         4       0      4
# LeasePlan Digital           Amsterdam             3         3       0      3
# Visser & Van Baars          Utrecht               3         3       2      3
# CarNext.com                 Amsterdam             3         3       0      3
# Nivel                       Utrecht               2         2       2      2
# Woonstad Rotterdam          Rotterdam             2         2       0      2
# Randstad Groep Nederland    Diemen                2         2       2      2
# ...

# %%
# Manual Industry adds for the top coompanies

# %%
jobs['Industry'][jobs['Company'] == 'Darwin Recruitment'] = 'Human resources en personeel' 
jobs['Industry'][jobs['Company'] == 'CarNext.com'] = 'Autosector' 
jobs['Industry'][jobs['Company'] == 'TU Delft'] = 'Onderwijs en scholen' 
jobs['Industry'][jobs['Company'] == 'Digital Power'] = 'Internet en software'
jobs['Industry'][jobs['Company'] == 'My Jewellery'] = 'Detailhandel'
jobs['Industry'][jobs['Company'] == 'Yacht'] = 'Human resources en personeel'
jobs['Industry'][jobs['Company'] == 'Good Company'] = 'Human resources en personeel'
jobs['Industry'][jobs['Company'] == 'Randstad Groep Nederland'] = 'Human resources en personeel'
jobs['Industry'][jobs['Company'] == 'Digital Decisions'] = 'Consultancy en zakelijke dienstverlening'
jobs['Industry'][jobs['Company'] == 'De Nederlandsche Bank'] = 'Banken en financiële dienstverlening'
jobs['Industry'][jobs['Company'] == 'SMQ'] = 'OverheidConsultancy en zakelijke dienstverlening'
jobs['Industry'][jobs['Company'] == 'Pacmed'] = 'Internet en software'
jobs['Industry'][jobs['Company'] == 'Dashmote'] = 'Internet en software'
jobs['Industry'][jobs['Company'] == 'DPG Media'] = 'Media, nieuws en uitgeverij'
jobs['Industry'][jobs['Company'] == 'OKE4U'] = 'Onderwijs en scholen'
# Out:
# C:\Users\tiina\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\tiina\anaconda3\lib\site-packages\pandas\core\generic.py:8767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\tiina\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
jobs['Industry'].value_counts().head(15)
# Out:
# Human resources en personeel                41
# Banken en financiële dienstverlening        27
# Consultancy en zakelijke dienstverlening    23
# Internet en software                        16
# Overheid                                    11
# Detailhandel                                 8
# Onderwijs en scholen                         7
# Transport en vrachtvervoer                   6
# Autosector                                   4
# Voedingsmiddelen en dranken                  4
# Gezondheidszorg                              4
# Consumentengoederen en dienstverlening       4
# Energie en nutsbedrijven                     3
# Verzekering                                  3
# Farmaceutica                                 2
# Name: Industry, dtype: int64

# %% [markdown]
# ### Salary

# %%
salaries = jobs[(~jobs['Min Salary'].isnull()) | jobs['Min Salary'] != 0]

# %%
salaries.describe()
# Out:
#           Min Salary     Max Salary  Normalized Sal Min  Normalized Sal Max  \
# count     109.000000     109.000000          109.000000          109.000000
# mean    13239.853211   17903.000000         3939.370031         5001.830275
# std     24123.281387   30860.491486         2107.324757         2142.788921
# min        11.000000      13.000000          500.000000          500.000000
# 25%      2575.000000    3470.000000         2900.000000         4000.000000
# 50%      3500.000000    4800.000000         3500.000000         5000.000000
# 75%      4533.000000    5800.000000         4166.666667         5800.000000
# max    160000.000000  160000.000000        16800.000000        16800.000000
#
#        Normalized Sal Avg  Posted_days
# count          109.000000   109.000000
# mean          4470.600153    10.394495
# std           2076.623877     6.617903
# min            500.000000     0.000000
# 25%           3358.500000     4.000000
# 50%           4359.000000    11.000000
# ...

# %%
salaries[salaries['Location Grouped'].isin(top_locs)].groupby(['Location Grouped', 'Title Grouped']).mean()
# Out:
#                                                               Min Salary  \
# Location Grouped Title Grouped
# Amsterdam        Business Intelligence Consultant/Engineer   2024.000000
#                  Data Analyst                                2259.250000
#                  Data Engineer                              63033.333333
#                  Data Scientist                             34896.200000
#                  Other                                       3637.000000
# Den Haag         Business Analyst                            2100.000000
#                  Business Intelligence Consultant/Engineer   6201.000000
#                  Data Engineer                               5000.000000
#                  Data Scientist                             40000.000000
#                  Other                                       3200.000000
# Eindhoven        Business Intelligence Consultant/Engineer   3677.000000
# ...

# %%
# Cleaning outliers
salaries = salaries[salaries['Normalized Sal Min'] != salaries['Normalized Sal Min'].max()]

# %%
# Min salaries
fig = plt.figure(figsize=(15, 12))
sns.boxplot(y='Normalized Sal Min', x='Title Grouped', data=salaries)
plt.xticks(np.arange(7), rotation=45)
plt.show()

# %%
# Max Salaries
fig = plt.figure(figsize=(15, 12))
sns.boxplot(y='Normalized Sal Max', x='Title Grouped', data=salaries)
plt.xticks(np.arange(7), rotation=45)
plt.show()

# %%
salaries.groupby('Title Grouped').mean().sort_values(by='Normalized Sal Max', ascending=False)
# Out:
#                                              Min Salary    Max Salary  \
# Title Grouped
# Data Engineer                              22034.000000  29315.291667
# Data Scientist                             20999.500000  29277.055556
# Business Analyst                            8001.090909  11447.727273
# Business Intelligence Consultant/Engineer   3248.538462   4335.615385
# Other                                      10723.947368  13953.157895
# Data Analyst                                8792.782609  11885.652174
#
#                                            Normalized Sal Min  \
# Title Grouped
# Data Engineer                                     4546.361111
# Data Scientist                                    4179.685185
# Business Analyst                                  3834.424242
# Business Intelligence Consultant/Engineer         3248.538462
# Other                                             3602.736842
# Data Analyst                                      3277.507246
#
# ...

# %%
# Salaries in top locations
fig = plt.figure(figsize=(15, 5))

selected_titles = ['Data Engineer', 'Data Scientist', 'Data Analyst', 'Business Intelligence Consultant/Engineer', 'Business Analyst']


sal_loc = salaries[salaries['Location Grouped'].isin(top_locs)].groupby(['Location Grouped', 'Title Grouped'])[['Normalized Sal Avg']].mean().reset_index()
sal_loc = sal_loc[sal_loc['Title Grouped'].isin(selected_titles)]

sns.barplot(x='Location Grouped', y='Normalized Sal Avg', hue='Title Grouped', data=sal_loc)
plt.legend(bbox_to_anchor=(0., 0.9, 1., .102), loc='upper right',
           ncol=2, borderaxespad=0.)
plt.show()

# %%
salaries[salaries['Location Grouped'].isin(top_locs)].groupby(['Location Grouped', 'Title Grouped']).mean().sort_values(by='Normalized Sal Max', ascending=False)
# Out:
#                                                               Min Salary  \
# Location Grouped Title Grouped
# Eindhoven        Data Engineer                                 70.000000
# Den Haag         Data Scientist                             40000.000000
# Amsterdam        Data Engineer                              63033.333333
# Den Haag         Data Engineer                               5000.000000
#                  Business Intelligence Consultant/Engineer   6201.000000
# Rotterdam        Other                                      41163.666667
#                  Data Engineer                              29245.500000
# Utrecht          Business Analyst                            3929.000000
# Rotterdam        Data Scientist                             31900.000000
# Amsterdam        Data Scientist                             34896.200000
# Eindhoven        Data Scientist                              3840.000000
# ...

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# With hypothesis testing we want to understand if there are significant differences between different atrributes in this dataset. We will examine the dataset regarding to Location, Titles, Salaries and Job Count.

# %%
def one_sided_test(x):
    pval =  x['P-value']/2
    stats = x['Stats']
    if (pval < 0.05) and (stats > 0):
        one_sided_greater = True
    else:
        one_sided_greater = False
    if (pval < 0.05) and (stats < 0):
         one_sided_smaller = True
    else:
         one_sided_smaller = False
    return one_sided_greater, one_sided_smaller

# %% [markdown]
# ## Location

# %% [markdown]
# ### Q1: Do different locations hire different proportion of specific roles than others?

# %% [markdown]
# H0: There is no difference in the proportion in the titles hired between different locations.
# H1: There is a difference of a certain region and the mean.

# %%
# Iterate through each selected titles

selected_titles = ['Data Engineer', 'Data Scientist', 'Data Analyst', 'Business Intelligence Consultant/Engineer', 'Business Analyst']

df_prop_test = pd.DataFrame(columns=['Location', 'Title', 'Stats', 'P-value', 'Title Count', 'Nobs', 'H0 Rejected' ])


for title in selected_titles:
    for loc in top_locs:
        title_count_pop = jobs['Title Grouped'][jobs['Title Grouped']==title].count()
        nobs_pop = jobs['Title Grouped'].count()
        pop_p = title_count_pop/nobs_pop 
    
        count_loc = jobs['Title Grouped'][(jobs['Title Grouped']==title) & (jobs['Location Grouped'] == loc)].count()
        nobs_loc = jobs['Title Grouped'][jobs['Location Grouped'] == loc].count()
        

        
        stats, pval = sm.stats.proportions_ztest(count_loc, nobs=nobs_loc, value=pop_p)
        
        h0 = pval < 0.05
        
        df_prop_test = df_prop_test.append({'Location':loc, 'Title': title,'Stats': stats, 'P-value': pval,'Title Count':count_loc, 'Nobs': nobs_loc, 'H0 Rejected': h0}, ignore_index=True)
        
    
        if pval < 0.05:
            print(f"The H0: {loc} hires the same proportion of {title}'s than the sample: t-stat {round(stats,2)}, p-value {pval}. The H0 can be rejected:", pval < 0.05)
df_prop_test[df_prop_test['H0 Rejected']==True]

# Apply onde sided test
df_prop_test['One sided Greater'] = df_prop_test.apply(lambda x: one_sided_test(x)[0], axis=1)
df_prop_test['One sided Smaller'] = df_prop_test.apply(lambda x: one_sided_test(x)[1], axis=1)
df_prop_test.head(60)
# Out:
# The H0: Utrecht hires the same proportion of Data Engineer's than the sample: t-stat -1.96, p-value 0.049425699144677517. The H0 can be rejected: True
# The H0: Den Haag hires the same proportion of Data Analyst's than the sample: t-stat -2.73, p-value 0.0063946458593359045. The H0 can be rejected: True
# The H0: Eindhoven hires the same proportion of Business Analyst's than the sample: t-stat -inf, p-value 0.0. The H0 can be rejected: True
# C:\Users\tiina\anaconda3\lib\site-packages\statsmodels\stats\weightstats.py:671: RuntimeWarning: divide by zero encountered in double_scalars
#   zstat = value / std_diff
#      Location                                      Title     Stats   P-value  \
# 0   Amsterdam                              Data Engineer  1.716101  0.086144
# 1     Utrecht                              Data Engineer -1.964901  0.049426
# 2   Rotterdam                              Data Engineer  0.345697  0.729571
# ...

# %%
# Visualize open titles per top5 locations
plt.rcParams["figure.figsize"] = [12, 5]


title = jobs.groupby(['Title Grouped', 'Location Grouped'])[['Company']].count().reset_index()
title.rename(columns={'Company': 'Job Count'}, inplace=True)
title = title[(title['Location Grouped'].isin(top_locs)) & (title['Title Grouped'].isin(selected_titles))].sort_values(by='Job Count')

pivot_titles = title.pivot(index='Location Grouped', columns='Title Grouped', values='Job Count')


pivot_titles.plot.bar(stacked=True)

plt.legend(loc='upper right',
           ncol=2, borderaxespad=0.)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Q2: Do different locations pay more to specific titles than in other locations?

# %% [markdown]
# H0: There is no difference in the mean salaries in the titles between different locations.
# H1: There is a difference of a certain region and the mean.

# %%
# Iterate through each selected titles

# Two-tailed test

from scipy.stats import ttest_ind

salary_columns = ['Normalized Sal Min', 'Normalized Sal Max', 'Normalized Sal Avg']


df_t_sal = pd.DataFrame(columns=['Location', 'Title', 'Salary Type', 'Stats', 'P-value', 'Sample', 'H0 Rejected'])



for title in selected_titles:
    for loc in top_locs:
        for sal in salary_columns:
            sal_title = jobs[sal][(salaries['Title Grouped']==title) & (jobs['Location Grouped'] != loc)]
            sal_title_loc = jobs[sal][(salaries['Title Grouped']==title) & (jobs['Location Grouped'] == loc)]
        
        
            n = len(sal_title_loc)
            
# H0 there is no difference between the groups 
# H1 there is a difference


            stats, pval = ttest_ind(sal_title_loc, sal_title, equal_var=False)
            h0 = pval < 0.05
    
            df_t_sal = df_t_sal.append({'Location':loc, 'Title':title, 'Salary Type':sal, 'Stats':stats, 'P-value':pval, 'Sample':n, 'H0 Rejected': h0}, ignore_index=True)             
    
            if pval < 0.05:
                print(f"\n H0: {loc} has a different mean in {sal} for {title}'s than the rest of sample: t-stat {round(stats,2)}, p-value {pval}. The H0 can be rejected:", pval < 0.05)
                
        
        # Apply one sided test
df_t_sal['One sided Greater'] = df_t_sal.apply(lambda x: one_sided_test(x)[0], axis=1)
df_t_sal['One sided Smaller'] = df_t_sal.apply(lambda x: one_sided_test(x)[1], axis=1)
# Out:
#  H0: Utrecht has a different mean in Normalized Sal Min for Data Scientist's than the rest of sample: t-stat -2.31, p-value 0.034797936889279575. The H0 can be rejected: True
#
#  H0: Utrecht has a different mean in Normalized Sal Max for Data Scientist's than the rest of sample: t-stat -2.39, p-value 0.03434766034386731. The H0 can be rejected: True
#
#  H0: Utrecht has a different mean in Normalized Sal Avg for Data Scientist's than the rest of sample: t-stat -2.45, p-value 0.028105636915282596. The H0 can be rejected: True
#
#  H0: Utrecht has a different mean in Normalized Sal Min for Business Intelligence Consultant/Engineer's than the rest of sample: t-stat -2.39, p-value 0.04231073647194287. The H0 can be rejected: True
#
#  H0: Eindhoven has a different mean in Normalized Sal Max for Business Intelligence Consultant/Engineer's than the rest of sample: t-stat 2.33, p-value 0.04222664973612963. The H0 can be rejected: True

# %%
df_t_sal.head(60)
# Out:
#      Location                                      Title         Salary Type  \
# 0   Amsterdam                              Data Engineer  Normalized Sal Min
# 1   Amsterdam                              Data Engineer  Normalized Sal Max
# 2   Amsterdam                              Data Engineer  Normalized Sal Avg
# 3     Utrecht                              Data Engineer  Normalized Sal Min
# 4     Utrecht                              Data Engineer  Normalized Sal Max
# 5     Utrecht                              Data Engineer  Normalized Sal Avg
# 6   Rotterdam                              Data Engineer  Normalized Sal Min
# 7   Rotterdam                              Data Engineer  Normalized Sal Max
# 8   Rotterdam                              Data Engineer  Normalized Sal Avg
# 9    Den Haag                              Data Engineer  Normalized Sal Min
# 10   Den Haag                              Data Engineer  Normalized Sal Max
# ...

# %% [markdown]
# ## Industry

# %% [markdown]
# ### Q3 Do different industries hire more specific profiles?
#
# - H0: Industries hire same proportion of different roles
# - H1: Industry hires more/less proportion of specific roles

# %%
# Iterate through each selected titles

top_5_ind = jobs.Industry.value_counts().head(5).index
print("Top 5 industries are", top_5_ind.values)

df_prop_ind = pd.DataFrame(columns=['Industry', 'Title', 'Stats', 'P-value', 'Title Count', 'Nobs', 'H0 Rejected'])


for title in selected_titles:
    for ind in top_5_ind:
        title_count_pop = jobs['Title Grouped'][(jobs['Title Grouped']==title) & (jobs['Industry'] != 'N/A')].count()
        nobs_pop = jobs['Title Grouped'][jobs['Industry'] != 'N/A'].count()
        pop_p = title_count_pop/nobs_pop 
    
        count_ind = jobs['Industry'][(jobs['Title Grouped']==title) & (jobs['Industry'] == ind)].count()
        nobs_ind = jobs['Industry'][jobs['Industry'] == ind].count()

        stats, pval = sm.stats.proportions_ztest(count_ind, nobs=nobs_ind, value=pop_p)
        
        h0 = pval < 0.05
        
        df_prop_ind = df_prop_ind.append({'Industry':ind, 'Title': title,'Stats': stats, 'P-value': pval,'Title Count':count_ind, 'Nobs': nobs_ind, 'H0 Rejected': h0}, ignore_index=True)
        
    
        if pval < 0.05:
            print(f"\nThe H0: {ind} hires the same proportion of {title}'s than the sample: t-stat {round(stats,2)}, p-value {pval}. The H0 can be rejected:", pval < 0.05)
            
df_prop_ind['One sided Greater'] = df_prop_ind.apply(lambda x: one_sided_test(x)[0], axis=1)
df_prop_ind['One sided Smaller'] = df_prop_ind.apply(lambda x: one_sided_test(x)[1], axis=1)
# Out:
# Top 5 industries are ['Human resources en personeel' 'Banken en financiële dienstverlening'
#  'Consultancy en zakelijke dienstverlening' 'Internet en software'
#  'Overheid']
#
# The H0: Banken en financiële dienstverlening hires the same proportion of Data Engineer's than the sample: t-stat -2.88, p-value 0.00392317026515866. The H0 can be rejected: True
#
# The H0: Internet en software hires the same proportion of Data Analyst's than the sample: t-stat -inf, p-value 0.0. The H0 can be rejected: True
#
# The H0: Consultancy en zakelijke dienstverlening hires the same proportion of Business Intelligence Consultant/Engineer's than the sample: t-stat 1.99, p-value 0.046373394270641376. The H0 can be rejected: True
#
# The H0: Human resources en personeel hires the same proportion of Business Analyst's than the sample: t-stat -3.83, p-value 0.0001279699261086762. The H0 can be rejected: True
#
# ...

# %%
df_prop_ind.head(60)
# Out:
#                                     Industry  \
# 0               Human resources en personeel
# 1       Banken en financiële dienstverlening
# 2   Consultancy en zakelijke dienstverlening
# 3                       Internet en software
# 4                                   Overheid
# 5               Human resources en personeel
# 6       Banken en financiële dienstverlening
# 7   Consultancy en zakelijke dienstverlening
# 8                       Internet en software
# 9                                   Overheid
# 10              Human resources en personeel
# 11      Banken en financiële dienstverlening
# 12  Consultancy en zakelijke dienstverlening
# 13                      Internet en software
# 14                                  Overheid
# 15              Human resources en personeel
# 16      Banken en financiële dienstverlening
# 17  Consultancy en zakelijke dienstverlening
# 18                      Internet en software
# 19                                  Overheid
# ...

# %% [markdown]
# ### Q4: Are the industries that pay more to certain titles?
#
# - H0: Industries pay on average the same amount for the same titles
# - H1: There are differences in salary based on industry for a specific title

# %%
# Iterate through each selected titles

# Two-tailed test

salary_columns = ['Normalized Sal Min', 'Normalized Sal Max', 'Normalized Sal Avg']


df_ind_sal = pd.DataFrame(columns=['Industry', 'Title', 'Salary Type', 'Stats', 'P-value', 'Sample', 'H0 Rejected'])


for title in selected_titles:
    for ind in top_5_ind:
        for sal in salary_columns:
            sal_ind = salaries[sal][(salaries['Title Grouped']==title) & (salaries['Industry'] != ind)]
            sal_title_ind = salaries[sal][(jobs['Title Grouped']==title) & (salaries['Industry'] == ind)]
        
        
            n = len(sal_title_ind)
            
# H0 there is no difference between the groups 
# H1 there is a difference


            stats, pval = ttest_ind(sal_title_ind, sal_ind, equal_var=False)
            h0 = pval < 0.05
    
            df_ind_sal = df_ind_sal.append({'Industry':ind, 'Title':title, 'Salary Type':sal, 'Stats':stats, 'P-value':pval, 'Sample':n, 'H0 Rejected': h0}, ignore_index=True)             
    
            if pval < 0.05:
                print(f"\n H0: {ind} has a different mean in {sal} for {title}'s than the rest of sample: t-stat {round(stats,2)}, p-value {pval}. The H0 can be rejected:", pval < 0.05)

# Apply one-sided tests                
df_ind_sal['One sided Greater'] = df_ind_sal.apply(lambda x: one_sided_test(x)[0], axis=1)
df_ind_sal['One sided Smaller'] = df_ind_sal.apply(lambda x: one_sided_test(x)[1], axis=1)
# Out:
# C:\Users\tiina\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3584: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\tiina\anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\tiina\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\tiina\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\tiina\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#  H0: Overheid has a different mean in Normalized Sal Min for Data Engineer's than the rest of sample: t-stat -2.1, p-value 0.04797759374836333. The H0 can be rejected: True
#
# ...

# %%
# df_ind_sal[df_ind_sal['Title'].isin(["Business Analyst"])]
df_ind_sal.head(60)
# Out:
#                                     Industry  \
# 0               Human resources en personeel
# 1               Human resources en personeel
# 2               Human resources en personeel
# 3       Banken en financiële dienstverlening
# 4       Banken en financiële dienstverlening
# 5       Banken en financiële dienstverlening
# 6   Consultancy en zakelijke dienstverlening
# 7   Consultancy en zakelijke dienstverlening
# 8   Consultancy en zakelijke dienstverlening
# 9                       Internet en software
# 10                      Internet en software
# 11                      Internet en software
# 12                                  Overheid
# 13                                  Overheid
# 14                                  Overheid
# 15              Human resources en personeel
# 16              Human resources en personeel
# 17              Human resources en personeel
# 18      Banken en financiële dienstverlening
# 19      Banken en financiële dienstverlening
# ...

# %% [markdown]
# ### Q5: Do industries hire more in specific locations?
#
# - H0: There is no difference in which industries hire to which locations
# - H1: Some industries are scattered to specific locations

# %%
top_5_ind = jobs.Industry.value_counts().head(5).index
print(top_5_ind)

df_prop_ind_loc = pd.DataFrame(columns=['Industry', 'Location', 'Stats', 'P-value', 'Title Count', 'Nobs', 'H0 Rejected'])


for loc in top_locs:
    for ind in top_5_ind:
        loc_count_pop = jobs['Location Grouped'][(jobs['Location Grouped']==loc) & (jobs['Industry'] != 'N/A')].count()
        nobs_pop = jobs['Location Grouped'][jobs['Industry'] != 'N/A'].count()
        pop_p = title_count_pop/nobs_pop 
    
        count_ind_loc = jobs['Location Grouped'][(jobs['Location Grouped']==loc) & (jobs['Industry'] == ind)].count()
        nobs_ind_loc = jobs['Location Grouped'][jobs['Industry'] == ind].count()

        stats, pval = sm.stats.proportions_ztest(count_ind_loc, nobs=nobs_ind_loc, value=pop_p)
        
        h0 = pval < 0.05
        
        df_prop_ind_loc = df_prop_ind_loc.append({'Industry':ind, 'Location': loc,'Stats': stats, 'P-value': pval,'Title Count':count_ind_loc, 'Nobs': nobs_ind_loc, 'H0 Rejected': h0}, ignore_index=True)
        
    
        if pval < 0.05:
            print(f"\nThe H0: {ind} hires the same proportion in {loc} than the sample: t-stat {round(stats,2)}, p-value {pval}. The H0 can be rejected:", pval < 0.05)# Conduct one sided tests

# Conduct one sided tests            
df_prop_ind_loc['One sided Greater'] = df_prop_ind_loc.apply(lambda x: one_sided_test(x)[0], axis=1) 
df_prop_ind_loc['One sided Smaller'] = df_prop_ind_loc.apply(lambda x: one_sided_test(x)[1], axis=1) 


df_prop_ind_loc.head(60)
# Out:
# Index(['Human resources en personeel', 'Banken en financiële dienstverlening',
#        'Consultancy en zakelijke dienstverlening', 'Internet en software',
#        'Overheid'],
#       dtype='object')
#
# The H0: Human resources en personeel hires the same proportion in Amsterdam than the sample: t-stat 2.19, p-value 0.02843348327045442. The H0 can be rejected: True
#
# The H0: Banken en financiële dienstverlening hires the same proportion in Amsterdam than the sample: t-stat 3.07, p-value 0.0021075211758592415. The H0 can be rejected: True
#
# The H0: Internet en software hires the same proportion in Amsterdam than the sample: t-stat 2.59, p-value 0.009682772042180971. The H0 can be rejected: True
#
# The H0: Internet en software hires the same proportion in Utrecht than the sample: t-stat -inf, p-value 0.0. The H0 can be rejected: True
#
# The H0: Overheid hires the same proportion in Utrecht than the sample: t-stat 2.25, p-value 0.024413835832523583. The H0 can be rejected: True
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# Bases on the analysis conducted in this project seems that there are plenty of opportunities for data professionals in the Netherlands for many different roles, industries and locations. For finding a best possible job for each individual they can take these key learnings from the analysis conducted. However, I would like to point out that this data is only applicable for June 2020, and it's gathered from indeed.nl, so it does not necessarily represent all jobs available in the industry.
#
# ### Summary for inferential statistics
#
# - ##### Q1: Do different locations hire different proportion of specific roles than others?
#     In June 2020:
#  - Utrecht hires smaller proportion of Data Engineers than other locations
#  - Den Haag hires smaller proportion of Data Analysts than other locations
#  - Eindhoven hires smaller proportion of Business Analysts than other locations
#
# - ##### Q2: Do different locations pay more to specific titles than in other locations?
#     (Sample size is also quite small here so take with a grain of salt)
#     In June 2020:
#  - Utrech pays smaller maximum salaries for Data Scientist than other locations
#  - Utrech pays smaller minimum salaries for BI Consultans/Engineers than other locations
#  - Eindhoven pays higher maximum salaries for BI Consultants/ Engineers
#
# - ##### Q3 Do different industries hire more specific profiles?
#     In June 2020:
#  - Banking and financial services hire smaller proportion of Data Engineers
#  - Consultancies hire bigger proportion of BI consultants/engineers than other industries
#  - HR & Recruitment hire smaller proportion of Business Analysts
#
# - ##### Q4: Are the industries that pay more to certain titles than other industries?
#     In June 2020:
#  - Goverment pays smaller minimum salaries to Data Engineers
#  - Goverment pays higher salaries for Data Analysts
#  - HR & Recruitment pays smaller salaries for Data Analysts
#  - Banking and Financial servies pays higher salaries for BI Consultant/Engineers that other industries.
#
# - ##### Q5: Do industries hire more in specific locations?
#     In June 2020:
#  - HR & Recruitment hires bigger proportion in Amsterdam and less in Rotterdam
#  - Banking and Financial services hire more in Amsterdam and less in Rotterdam
#  - Internet & Software hires more in Amsterdam
#  - Goverment hires more in Utrecht
