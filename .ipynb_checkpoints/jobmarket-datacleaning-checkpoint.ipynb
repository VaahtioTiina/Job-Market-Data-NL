# %% [markdown]
# # Job Market for Data Professionals - Data Cleaning
#
# This notebook presents the second part of the project in analyzing the job market for data professionals.
#
# This notebook focuses on cleaning our dataset and transforming it to exploratory-friendly format.

# %%
# Import libraries 
import pandas as pd
import re
import numpy as np
from datetime import datetime, timedelta, date

# %%
jobs = pd.read_csv('jobs_all_base.csv')
jobs.head()
# Out:
#                                    Title    Location             Company  \
# 0     CUSTOMS ADVISOR DATA ANALIST BREDA       Breda                 DHL
# 1  Specialist Business Intelligence (BI)   Rotterdam              Milgro
# 2          Business Intelligence Analist  Nieuwegein        Fysioholland
# 3                        Digital Analyst    Rijswijk  TUI Nederland N.V.
# 4                  Data analist parttime   Amsterdam             Work-on
#
#                       Salary          Since  Description        Company Url  \
# 0  €2.900 - €3.500 per maand  Net geplaatst          NaN           /cmp/DHL
# 1                        NaN  Net geplaatst          NaN        /cmp/Milgro
# 2                        NaN  Net geplaatst          NaN  /cmp/Fysioholland
# 3                        NaN  Net geplaatst          NaN     /cmp/Tui-Group
# 4          €11 - €13 per uur  Net geplaatst          NaN      /cmp/Work--on
#
#                             Industry     Company size
# 0         Transport en vrachtvervoer  Meer dan 10.000
# 1                                NaN              NaN
# 2                                NaN              NaN
# 3  Restaurants, reizen en vrije tijd  Meer dan 10.000
# 4       Human resources en personeel        11 tot 50

# %%
jobs.shape
# Out:
# (1500, 9)

# %%
jobs.dtypes
# Out:
# Title            object
# Location         object
# Company          object
# Salary           object
# Since            object
# Description     float64
# Company Url      object
# Industry         object
# Company size     object
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
# Top 15 uncleaned titles
jobs.Title.value_counts().head(15)
# Out:
# Data Engineer                       22
# Data Scientist                      14
# Data Analist                        13
# Software Engineer                    9
# Business Analist                     7
# Business Controller                  7
# Business Intelligence Specialist     7
# Business Analyst                     6
# Business Intelligence Consultant     6
# DevOps Engineer                      6
# Data scientist                       5
# Business Intelligence Analist        4
# Senior Data Scientist                4
# Data Analyst                         4
# Security Engineer                    4
# Name: Title, dtype: int64

# %%
og_titles = []

regular_expressions = [r'data[- ]anal[yi]st', r'data[- ]scien', r'data[- ]engineer', r'business[- ]anal', r'business[- ]intelli', r' bi ', r'machine learning[- ]engineer', r'artificial intelligence[- ]engi',r'translat', r'analytics[- ]consul', r'data[- consult]', r'data']
    
for title in jobs['Title']:
    for key in regular_expressions:
        match = re.search(key, title.lower())
        if match:
            og_titles.append(title)

# %%
len(og_titles)
# Out:
# 954

# %%
sorted(og_titles)
# Out:
# ['(Afstudeer)stages Business Intelligence binnen Asset Managem...',
#  '(Big) Data Engineer',
#  '(Big) Data Engineer',
#  '(Big) Data Engineer',
#  '(Big) Data Engineer',
#  '(Big) Data Engineer',
#  '(Big) Data Engineer',
#  '(Junior) Data Engineer (m/v)',
#  '(Junior) Data Engineer (m/v)',
#  '(Junior) Data Engineer (m/v)',
#  '(Lead) engineer installatietechniek (E en/of W) datacenters',
#  '(Lead) engineer installatietechniek (E en/of W) datacenters',
#  '(Senior) Business Analyst for Risk & Finance',
#  '(Senior) Business Analyst for the Accounting Tribe',
#  '(Senior) Data-analist',
#  '(Senior) Data-analist',
#  '(Senior) Data-analist',
#  '(Senior) Translational Scientist - Oncology (36-40 hrs/wk)',
#  'AI & Data Science Internship at ABN AMRO',
#  'AI & Data Science Internship at ABN AMRO',
#  'AI & Data Science Internship at ABN AMRO',
#  'Administratief Medewerker Databeheer & Kwaliteit | Punten en...',
#  'Advisor Data & Technology - Assurance',
#  'Advisor Data & Technology - Assurance',
#  'Analist business intelligence bij Link Asset Services (senio...',
#  'Applicatiebeheerder / Data analist',
#  'Applicatiebeheerder / Data analist',
#  'Applicatiebeheerder / Data analist',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Applied Data Scientist with a Data Engineering Focus',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Data Scientist vacature',
#  'Artificial Intelligence Translator (m/f)',
#  'Assistent Zorginkoper/ Business Analist MSZ',
#  'Azure Data Engineer',
#  'Azure Data Engineer',
#  'Azure Data Engineer',
#  'Azure Data Platform Engineer',
#  'Azure Data Platform Engineer',
#  'BI Consultant | Microsoft BI | Nationale Veiligheid',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI Developer / Data Engineer / ETL / Duizenden gebruikers',
#  'BI and Data Insight Lead',
#  'BI and Data Insight Lead',
#  'BUSINESS ANALYST',
#  'Big Data Engineer',
#  'Big Data Engineer',
#  'Big Data Engineer',
#  'Big Data Engineer A.I.',
#  'Big Data Engineer A.I.',
#  'Big Data Engineer A.I.',
#  'Big Data Solution Architect',
#  'Big Data Solution Architect',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'BusDev/Sales Manager -SAAS-DATA-Germany-Rotterdam-€50K-€80K+...',
#  'BusDev/Sales Manager -SAAS-DATA-Germany-Rotterdam-€50K-€80K+...',
#  'Business & Data Analyst',
#  'Business & Data Analyst',
#  'Business & Data Analyst',
#  'Business & Data Analyst',
#  'Business & Data Analyst',
#  'Business & Data Analyst',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist',
#  'Business Analist (32-40 uur)',
#  'Business Analist - Projectleider',
#  'Business Analist / Projectleider Utrecht',
#  'Business Analist Customer Contact Cent',
#  'Business Analist Finance & Risk Hypotheken',
#  'Business Analist Forecasting',
#  'Business Analist Global KYC (m/v)',
#  'Business Analist Global KYC (m/v)',
#  'Business Analist in publieke sector',
#  'Business Analist | Financial Risk | Product Owner',
#  'Business Analist – Projectleider',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst (BI)',
#  'Business Analyst (Home & Personal Care)',
#  'Business Analyst - Statutory & Regulatory Reporting (AnaCred...',
#  'Business Analyst - Supply Chain Professional',
#  'Business Controller (Power BI Developer)',
#  'Business Controller (Power BI Developer)',
#  'Business Data Analist (vaste baan Amsterdam)',
#  'Business Data Analist (vaste baan Amsterdam)',
#  'Business Data Analist (vaste baan Amsterdam)',
#  'Business IT (afstudeer)stage inrichten Business Intelligence',
#  'Business Intelligence & Digital Analytics - Global eCommerce...',
#  'Business Intelligence (BI) Consultant',
#  'Business Intelligence (BI) professional',
#  'Business Intelligence - Data Warehouse Internship',
#  'Business Intelligence - Data Warehouse Internship',
#  'Business Intelligence - Data Warehouse Internship',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / Data Warehouse Developer',
#  'Business Intelligence / ICT Stagiair(e)',
#  'Business Intelligence Analist',
#  'Business Intelligence Analist',
#  'Business Intelligence Analist',
#  'Business Intelligence Analist',
#  'Business Intelligence Analist vacature',
#  'Business Intelligence Architect',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant',
#  'Business Intelligence Consultant Medior rol',
#  'Business Intelligence Developer',
#  'Business Intelligence Developer',
#  'Business Intelligence Developer',
#  'Business Intelligence Engineer vacature',
#  'Business Intelligence Internship',
#  'Business Intelligence Lead',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist',
#  'Business Intelligence Specialist | Tiel',
#  'Business Intelligence Specialist/ Datawarehouse / ETL',
#  'Business Intelligence Specialist/ Datawarehouse / ETL',
#  'Business Intelligence Support Consultant',
#  'Business Intelligence Teamlead',
#  'Business Intelligence in IT',
#  'Business Intelligence specialist (zorg sector)',
#  'Business analist',
#  'Business analist',
#  'Business analyst & inkoper',
#  'Business intelligence Lead (NL)',
#  'Business intelligence- (BI-)ontwikkelaar',
#  'Business- en Procesengineer / (Data) Analist',
#  'CONSULTANT DATA SCIENCE & ADVANCED ANALYTICS',
#  'CONSULTANT DATA SCIENCE & ADVANCED ANALYTICS',
#  'CONSULTANT DATA SCIENCE & ADVANCED ANALYTICS',
#  'CRM Data Analyst',
#  'CRM Data Analyst',
#  'CRM Data Analyst',
#  'CUSTOMS ADVISOR DATA ANALIST BREDA',
#  'CUSTOMS ADVISOR DATA ANALIST BREDA',
#  'CUSTOMS ADVISOR DATA ANALIST BREDA',
#  'Chapter Lead Business Analyst Global KYC (Data)',
#  'Chapter Lead Business Analyst Global KYC (Data)',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering',
#  'Chapter Lead Data Engineering - Financial Crime & RegTech',
#  'Chapter Lead Data Engineering - Financial Crime & RegTech',
#  'Chapter Lead Data Engineering - Financial Crime & RegTech',
#  'Cognitive & Data Analist',
#  'Cognitive & Data Analist',
#  'Cognitive & Data Analist',
#  'Consultant Data & Analytics (Data analist, reporting analist...',
#  'Consultant Data & Analytics (Data analist, reporting analist...',
#  'Consultant Data & Analytics (Data analist, reporting analist...',
#  'Consultant/Senior Data Analist',
#  'Consultant/Senior Data Analist',
#  'Consultant/Senior Data Analist',
#  'Content Marketeer - GoDataDriven',
#  'Customer Data Analist',
#  'Customer Data Analist',
#  'Customer Data Analist',
#  'Customer Data Analyst Leeuwarden',
#  'Customer Data Analyst Leeuwarden',
#  'Customer Data Analyst Leeuwarden',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'DATA SCIENTIST PERMANENT POSITION SOUTH-HOLLAND',
#  'Data & Automation Engineering Lead',
#  'Data & Automation Engineering Lead',
#  'Data & BI Analyst',
#  'Data & BI Analyst',
#  'Data & BI Analyst',
#  'Data & Growth Engineer',
#  'Data & Growth Engineer',
#  'Data & Growth Engineer',
#  'Data & Growth Engineer',
#  'Data - Analist',
#  'Data - Analist',
#  'Data / Business Intelligence Specialist',
#  'Data / Business Intelligence Specialist',
#  'Data / Business Intelligence Specialist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (Junior/Medior)',
#  'Data Analist (marketing)',
#  'Data Analist (marketing)',
#  'Data Analist (marketing)',
#  'Data Analist Vernet',
#  'Data Analist Vernet',
#  'Data Analist Vernet',
#  'Data Analist Zorg',
#  'Data Analist Zorg',
#  'Data Analist Zorg',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst - App Optimisation',
#  'Data Analyst - App Optimisation',
#  'Data Analyst - App Optimisation',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst / Reporting Expert',
#  'Data Analyst / Reporting Expert (NL)',
#  'Data Analyst / Reporting Expert (NL)',
#  'Data Analyst / Reporting Expert (NL)',
#  'Data Analyst Sales & Marketing Internship / Graduate',
#  'Data Analyst Sales & Marketing Internship / Graduate',
#  'Data Analyst Sales & Marketing Internship / Graduate',
#  'Data Analytics Manager at Customer Support',
#  'Data Analytics Manager at Customer Support',
#  'Data Analytics specialist - consultant',
#  'Data Analytics specialist - consultant',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer (BI-Tech)',
#  'Data Engineer (BI-Tech)',
#  'Data Engineer (BI-Tech)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (ervaren)',
#  'Data Engineer (permanent position)',
#  'Data Engineer (permanent position)',
#  'Data Engineer (permanent position)',
#  'Data Engineer - RTL Nederland',
#  'Data Engineer - RTL Nederland',
#  'Data Engineer - RTL Nederland',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer AWS/GCP (Temporary position)',
#  'Data Engineer Azure Data Bricks',
#  'Data Engineer Azure Data Bricks',
#  'Data Engineer Azure Data Bricks',
#  'Data Engineer Conusltant',
#  'Data Engineer Conusltant',
#  'Data Engineer Conusltant',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer Experienced in AWS or GCP (Permanent Position)',
#  'Data Engineer High-Tech',
#  'Data Engineer High-Tech',
#  'Data Engineer High-Tech',
#  'Data Engineer Intern',
#  'Data Engineer Intern',
#  'Data Engineer Intern',
#  'Data Engineer PortalOne',
#  'Data Engineer PortalOne',
#  'Data Engineer PortalOne',
#  'Data Engineer voor vergelijkingssite',
#  'Data Engineer voor vergelijkingssite',
#  'Data Engineer voor vergelijkingssite',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Engineer | AWS | Cloud | Finance',
#  'Data Engineering Consultant',
#  'Data Engineering Consultant',
#  'Data Engineering Consultant',
#  'Data Management Analyst',
#  'Data Management Analyst',
#  'Data Management Professional (m/f)',
#  'Data Management Professional (m/f)',
#  'Data Migration specialist (Interim)',
#  'Data Migration specialist (Interim)',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Science Consultant',
#  'Data Science Consultant',
#  'Data Science Consultant',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Consultant (JUNIOR/MEDIOR/SENIOR)',
#  'Data Science Engineer',
#  'Data Science Engineer',
#  'Data Science Engineer',
#  'Data Science Lead',
#  'Data Science Lead',
#  'Data Science Lead',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Medior)',
#  'Data Scientist (Medior)',
#  'Data Scientist (Medior)',
#  'Data Scientist 0,8 fte',
#  'Data Scientist 0,8 fte',
#  'Data Scientist 0,8 fte',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Conversational AI (f/m)',
#  'Data Scientist Medior',
#  'Data Scientist Medior',
#  'Data Scientist Medior',
#  'Data Scientist in publieke sector',
#  'Data Scientist in publieke sector',
#  'Data Scientist in publieke sector',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist – Product Owner (EN)',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Scientist/Commercial Analyst BritNed',
#  'Data Specialist',
#  'Data Specialist',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Visualisatie Expert',
#  'Data Visualisatie Expert',
#  'Data Visualization expert',
#  'Data Visualization expert',
#  'Data Warehouse Engineer (Amsterdam)',
#  'Data Warehouse Engineer (Amsterdam)',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist',
#  'Data analist - Zutphen',
#  'Data analist - Zutphen',
#  'Data analist - Zutphen',
#  'Data analist Vernet',
#  'Data analist Vernet',
#  'Data analist Vernet',
#  'Data analist in accountancy (junior)',
#  'Data analist in accountancy (junior)',
#  'Data analist in accountancy (junior)',
#  'Data analist in accountancy branche',
#  'Data analist in accountancy branche',
#  'Data analist in accountancy branche',
#  'Data analist parttime',
#  'Data analist parttime',
#  'Data analist parttime',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data analist/GIS specialist Vastgoedadvisering',
#  'Data custodian',
#  'Data custodian',
#  'Data custodian',
#  'Data custodian',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data engineer',
#  'Data oriented Financial Economic Crime Intelligence Analyst',
#  'Data oriented Financial Economic Crime Intelligence Analyst',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist',
#  'Data scientist voor NLP-gerelateerde ML',
#  'Data scientist voor NLP-gerelateerde ML',
#  'Data scientist voor NLP-gerelateerde ML',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data scientist/Business analyst Huizen (32-40 uur)',
#  'Data-analist OV en Mobiliteit',
#  'Data-analist OV en Mobiliteit',
#  'Data-analist OV en Mobiliteit',
#  'Data-engineer Splunk',
#  'Data-engineer Splunk',
#  'Data-engineer Splunk',
#  'Data-engineer per 1 september',
#  'Data-engineer per 1 september',
#  'Data-engineer per 1 september',
#  'DataOps Engineer',
#  'DataOps Engineer',
#  'Database Engineer',
#  'Database Marketeer',
#  'Database Marketeer',
#  'Databasebeheerder',
#  'Datacenter Engineer',
#  'Datacenter Engineer',
#  'Datalake/Hadoop Beheerder',
#  'Datalake/Hadoop Beheerder',
#  'Dataplatform / EDW Beheerder',
#  'Datawarehouse Engineer',
#  'Datawarehouse Engineer',
#  'DevOps Data Engineer',
#  'DevOps Data Engineer',
#  'DevOps Data Engineer',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Data Management Developer',
#  'DevOps Engineer - Data Management Developer',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'DevOps Engineer - Developer Self Service & Data Science',
#  'DevOps Engineer Data',
#  'Developer Business Intelligence en Datawarehouse',
#  'Developer Business Intelligence en Datawarehouse',
#  'Docent Software Engineering & Big data',
#  'EXPERIENCED DATA ENGINEER',
#  'EXPERIENCED DATA ENGINEER',
#  'EXPERIENCED DATA ENGINEER',
#  'Electrical Engineer - Data Centre - Amsterdam',
#  'Electrical Engineer - Data Centre - Amsterdam',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineer Scheepsbouw / Data Analist',
#  'Engineering Manager - Distributed Data Systems',
#  'Engineering Manager - Distributed Data Systems',
#  'FREELANCE BI/DATA ANALYTICS OVERHEID',
#  'FREELANCE BI/DATA ANALYTICS OVERHEID',
#  'Financial Reporting Data Expert',
#  'Financial Reporting Data Expert',
#  'Financieel Consultant Business Intelligence',
#  'Fullstack Java Engineer - Data platform for sports! - 55K',
#  'Fullstack Java Engineer - Data platform for sports! - 55K',
#  'Fullstack PHP Developer Data Science Producten',
#  'Fullstack PHP Developer Data Science Producten',
#  'Fullstack PHP Developer Data Science Producten',
#  'Functioneel beheerder / Business Analist DATA',
#  'Functioneel beheerder / Business Analist DATA',
#  'HBO Meewerkstage Data Science',
#  'HBO Meewerkstage Data Science',
#  'HBO Meewerkstage Data Science',
#  'HBO/WO Stage data analyse bij een innovatief zorgbedrijf',
#  'HBO/WO Stage data analyse bij een innovatief zorgbedrijf',
#  'Hadoop Data Engineer Java Developer High Frequency Trading',
#  'Hadoop Data Engineer Java Developer High Frequency Trading',
#  'Hadoop Data Engineer Java Developer High Frequency Trading',
#  'Head of Data Management',
#  'Head of Data Management',
#  'Head of Strategy & Business Intelligence',
#  'IT Traineeship Data Infra Engineer',
#  'IT Traineeship Data Infra Engineer',
#  'Informatica Business Intelligence (BI) Consultant',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist',
#  'Informatie Analist / Data Analist / BI',
#  'Informatie Analist / Data Analist / BI',
#  'Informatie Analist / Data Analist / BI',
#  'Informatieanalist BI - D&A Commercie - Utrecht',
#  'Information & Data Architect(e) Clearing',
#  'Information & Data Architect(e) Clearing',
#  'Interim Professional Data & Procesanalyse',
#  'Interim Professional Data & Procesanalyse',
#  'Internship Business Intelligence',
#  'Internship Data Science',
#  'Internship Data Science',
#  'Internship Data Science',
#  'Internship: Data Science',
#  'Internship: Data Science',
#  'Internship: Data Science',
#  'Internship: Data Scientist – developer',
#  'Internship: Data Scientist – developer',
#  'Internship: Data Scientist – developer',
#  'Internship: Data Scientist – modeller',
#  'Internship: Data Scientist – modeller',
#  'Internship: Data Scientist – modeller',
#  'Jr. Music Data Analyst',
#  'Jr. Music Data Analyst',
#  'Jr. Music Data Analyst',
#  'Junior BI Consultant | Microsoft BI | Nationale Veiligheid',
#  'Junior Business Intelligence Specialist',
#  'Junior Consultant Business Intelligence',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist',
#  'Junior Data Analist Remediation',
#  'Junior Data Analist Remediation',
#  'Junior Data Analist Remediation',
#  'Junior Data Analyst',
#  'Junior Data Analyst',
#  'Junior Data Analyst',
#  'Junior Data Analyst',
#  'Junior Data Analyst',
#  'Junior Data Analyst',
#  'Junior Data Consultant',
#  'Junior Data Consultant',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Engineer',
#  'Junior Data Management Consultant',
#  'Junior Data Management Consultant',
#  'Junior Marketing Data Scientist',
#  'Junior Marketing Data Scientist',
#  'Junior Marketing Data Scientist',
#  'Junior Reporting & Data Analyst I',
#  'Junior Reporting & Data Analyst I',
#  'Junior Reporting & Data Analyst I',
#  'Junior Strategy & Business Analyst',
#  'Junior Strategy & Business Analyst',
#  'Junior data analist (accountancy)',
#  'Junior data analist (accountancy)',
#  'Junior data analist (accountancy)',
#  'Junior data engineer',
#  'Junior data engineer',
#  'Junior data engineer',
#  'Junior data-analist',
#  'Junior data-analist',
#  'Junior data-analist',
#  'Junior dataspecialist',
#  'Junior dataspecialist',
#  "Junior dataspecialist 'Panel en survey onderzoek'",
#  "Junior dataspecialist 'Panel en survey onderzoek'",
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Kwantitatief onderzoeker / Data Scientist',
#  'Lead Data Engineer',
#  'Lead Data Engineer',
#  'Lead Data Engineer',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Engineer (PreSales)',
#  'Lead Data Science',
#  'Lead Data Science',
#  'Lead Data Science',
#  'Lead Search Data Scientist',
#  'Lead Search Data Scientist',
#  'Lead Search Data Scientist',
#  'Lead data-scientist',
#  'Lead data-scientist',
#  'Lead data-scientist',
#  'MANAGER BUSINESS INTELLIGENCE IN NAARDEN',
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'MEDIOR/SENIOR DATA SCIENTIST',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer (junior/medior)',
#  'Machine Learning Engineering Internship @start-up in Delft',
#  'Machine learning engineer',
#  'Manager Data Analytics',
#  'Manager Data Analytics',
#  'Manager Team Databeheer',
#  'Marketing Data Specialist',
#  'Marketing Data Specialist',
#  'Master Data Analyst',
#  'Master Data Analyst',
#  'Master Data Analyst',
#  'Master Data Specialist',
#  'Master Data Specialist',
#  'Master Data Specialist / Jr Data Analyst',
#  'Master Data Specialist / Jr Data Analyst',
#  'Master Data Specialist / Jr Data Analyst',
#  'Medewerker data & analytics',
#  'Medewerker data & analytics',
#  'Medewerker datamanagement en kwaliteit',
#  'Medior BI Professional',
#  'Medior Business Intelligence (BI) consultant',
#  'Medior Consultant Business Intelligence',
#  'Medior Data Analist',
#  'Medior Data Analist',
#  'Medior Data Analist',
#  'Medior Data Consultant',
#  'Medior Data Consultant',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Engineer',
#  'Medior Data Management Consultant',
#  'Medior Data Management Consultant',
#  'Medior SQL Ontwikkelaar / Database Developer / Analist',
#  'Medior/Senior Data Engineer',
#  'Medior/Senior Data Engineer',
#  'Medior/Senior Data Engineer',
#  'Microsoft BI Consultant bij All Your BI',
#  'Microsoft Business Intelligence (BI) Consultant',
#  'Microsoft Business Intelligence (cloud) Specialist',
#  'Modelling Data Analyst',
#  'Modelling Data Analyst',
#  'Modelling Data Analyst',
#  'Modelling Data Analyst Liability Management)',
#  'Modelling Data Analyst Liability Management)',
#  'Modelling Data Analyst Liability Management)',
#  'Nieuwe Business Intelligence Consultants gezocht!',
#  'Opdracht: Data Engineer',
#  'Opdracht: Data Engineer',
#  'Opdracht: Data Engineer',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'Postdoc Data Platforms and Business Models',
#  'Postdoc Data Platforms and Business Models',
#  'Postdoc Humanizing Acoustic Data for Wellbeing',
#  'Postdoc Humanizing Acoustic Data for Wellbeing',
#  'Principal Data Analist',
#  'Principal Data Analist',
#  'Principal Data Analist',
#  'Principal Data Scientist',
#  'Principal Data Scientist',
#  'Principal Data Scientist',
#  'Product Owner Data & Analyse',
#  'Product Owner Data & Analyse',
#  'Product Owner Data & Analyse',
#  'Product Owner Data & Analyse',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Python Data & Machine Learning Engineer',
#  'Python Data & Machine Learning Engineer',
#  'Python Data & Machine Learning Engineer',
#  'Recruitment Consultant Amsterdam Big Data',
#  'SAP Data Analist',
#  'SAP Data Analist',
#  'SAP Data Analist',
#  'Scientific Data Engineer',
#  'Scientific Data Engineer',
#  'Scientific Data Engineer',
#  'Senior Artificial Intelligence Engineer',
#  'Senior BI Consultant',
#  'Senior BI Consultant',
#  'Senior BI Consultant',
#  'Senior BI Consultant voor Logistiek Pakketten',
#  'Senior Big Data Engineer (>4 jaar ervaring)',
#  'Senior Big Data Engineer (>4 jaar ervaring)',
#  'Senior Big Data Engineer (>4 jaar ervaring)',
#  'Senior Business Analist',
#  'Senior Business Analist Fraud & Risk',
#  'Senior Business Analyst',
#  'Senior Business Intelligence (BI) consultant',
#  'Senior Business Intelligence Consultant',
#  'Senior Business-Analist',
#  'Senior Cloud Architect / Data Engineer',
#  'Senior Cloud Architect / Data Engineer',
#  'Senior Cloud Architect / Data Engineer',
#  'Senior Consultant Business Intelligence',
#  'Senior Data Analist Remediation',
#  'Senior Data Analist Remediation',
#  'Senior Data Analist Remediation',
#  'Senior Data Consultant',
#  'Senior Data Consultant',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer / Architect',
#  'Senior Data Engineer / Architect',
#  'Senior Data Engineer / Architect',
#  'Senior Data Engineer BI - D&A Commercie - Utrecht',
#  'Senior Data Engineer BI - D&A Commercie - Utrecht',
#  'Senior Data Engineer BI - D&A Commercie - Utrecht',
#  'Senior Data Engineer BI - D&A Commercie - Utrecht',
#  'Senior Data Engineer FR&R',
#  'Senior Data Engineer FR&R',
#  'Senior Data Engineer FR&R',
#  'Senior Data Intelligence Specialist',
#  'Senior Data Intelligence Specialist',
#  'Senior Data Management Consultant',
#  'Senior Data Management Consultant',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist - Amsterdam',
#  'Senior Data Scientist Consultant',
#  'Senior Data Scientist Consultant',
#  'Senior Data Scientist Consultant',
#  'Senior Data Transcript Engineer',
#  'Senior Data Transcript Engineer',
#  'Senior Data warehouse Engineer',
#  'Senior Data warehouse Engineer',
#  'Senior Data-Scientist',
#  'Senior Data-Scientist',
#  'Senior Data-Scientist',
#  'Senior Data-analist',
#  'Senior Data-analist',
#  'Senior Data-analist',
#  'Senior Lead Data Analytics',
#  'Senior Lead Data Analytics',
#  'Senior Machine Learning Engineer',
#  'Senior Machine Learning Engineer',
#  'Senior Modelling Data Analyst',
#  'Senior Modelling Data Analyst',
#  'Senior Modelling Data Analyst',
#  'Senior Technology Data Engineer',
#  'Senior Technology Data Engineer',
#  'Senior Technology Data Engineer',
#  'Senior consultant business intelligence',
#  'Slimme junior data-analist/ programmeur',
#  'Slimme junior data-analist/ programmeur',
#  'Slimme junior data-analist/ programmeur',
#  'Software Engineer – Dataplatform',
#  'Solution Architect (C#, .NET, Azure, Data driven)',
#  'Solution Architect (C#, .NET, Azure, Data driven)',
#  'Specialist Business Intelligence (BI)',
#  'Sr. Business Intelligence Developer',
#  'Sr. Data Scientist',
#  'Sr. Data Scientist',
#  'Sr. Data Scientist',
#  'Sr. Machine Learning Engineer',
#  'Supply Chain Master Data Analyst',
#  'Supply Chain Master Data Analyst',
#  'Supply Chain Master Data Analyst',
#  'System & Data Engineer',
#  'System & Data Engineer',
#  'System & Data Engineer',
#  'System & Data Engineer',
#  'System & Data Engineer',
#  'System & Data Engineer',
#  'TRAINEESHIP: DATA SCIENCE & ANALYTICS EXCELLENCE PROGRAM',
#  'TRAINEESHIP: DATA SCIENCE & ANALYTICS EXCELLENCE PROGRAM',
#  'TRAINEESHIP: DATA SCIENCE & ANALYTICS EXCELLENCE PROGRAM',
#  'Teammanager business analytics',
#  'Tech & Data Manager',
#  'Tech & Data Manager',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Tech Lead Data Engineering',
#  'Technisch Data Analist',
#  'Technisch Data Analist',
#  'Technisch Data Analist',
#  'Tenure Track position Data Driven Modelling in Computational...',
#  'Tenure Track position Data Driven Modelling in Computational...',
#  'Thesis Research - Business Intelligence',
#  'Trainee Business Intelligence Consultant',
#  'Trainee Data Engineer | Lady Legends',
#  'Trainee Data Engineer | Lady Legends',
#  'Trainee Data Engineer | Lady Legends',
#  'Traineeship Business Analist (Pensioenen)',
#  'Traineeship Data',
#  'Traineeship data specialist overheid',
#  'Traineeship data specialist overheid',
#  'Traineeship data specialist overheid',
#  'Traineeship data specialist overheid',
#  'Voice data-engineer',
#  'Voice data-engineer',
#  'Voice data-engineer',
#  'business intelligence support specialist',
#  'data scientist',
#  'data scientist',
#  'data scientist',
#  'senior engineer Big Data System',
#  'senior engineer Big Data System']

# %%
og_titles = set(og_titles)

# %%
# Examine titles that dont' fall the the categories above

jobs[~jobs['Title'].isin(og_titles)]['Title'].value_counts().head(60)
# Out:
# Software Engineer                                             9
# Business Controller                                           7
# DevOps Engineer                                               6
# Scrum Master                                                  4
# Security Engineer                                             4
# Controller Zorg                                               3
# Financial Controller                                          3
# Informatie Analist                                            3
# Cloud Engineer                                                3
# Systeembeheerder                                              3
# Senior RF Application and Characterization Engineer           3
# Controller                                                    3
# Backend Developer                                             3
# Product Owner                                                 3
# Field Service Engineer                                        3
# Reliability Engineer                                          3
# Senior DevOps Engineer / Scrum Master                         3
# Medewerker Engineering                                        3
# Senior DevOps Engineer                                        2
# Maintenance Engineer                                          2
# Software Developer                                            2
# Software Developer (junior)                                   2
# Cognos Ontwikkelaar BI                                        2
# Risk Analyst                                                  2
# Brand Manager                                                 2
# Adviseur CIO                                                  2
# Engineer                                                      2
# Site Reliability Engineer                                     2
# Senior Support Manager (DVOW Equipment Fleet, Netherlands)    2
# Senior Project Manager                                        2
# R&D Manager Signal Processing Group – imec The Netherlands    2
# FP&A Analyst                                                  2
# Cloud Security Engineer                                       2
# Supply Chain Engineer                                         2
# Electrical Engineer                                           2
# Frontend Developer                                            2
# Mechatronics Engineer                                         2
# Content Specialist                                            2
# Automation Engineer                                           2
# Quality Engineer                                              2
# Process Engineer                                              2
# Traineeship Finance                                           2
# Field Application Scientist                                   2
# Research Analist (celkweek, ELISA, WB)                        2
# Technical Sales Engineer Benelux                              2
# Manufacturing engineer                                        2
# Support Engineer IT                                           2
# Associate Scientist USP                                       2
# Security Risk Consultant                                      2
# Financial controller                                          2
# Senior Software Engineer - DevOps/Full Stack                  2
# Portfolio Dependencies Manager                                2
# Informatiemanager                                             2
# Technical Product Consultant                                  2
# Senior Controller                                             2
# Senior Software Engineer – Backend/Fullstack                  2
# Werkvoorbereider / Ordermanager Service & Projecten           2
# Senior Back-End Developer                                     2
# Test Engineer                                                 2
# Support Engineer                                              2
# Name: Title, dtype: int64

# %% [markdown]
# We will drop the above titles from our analysis, as they don't fall to the traditional categories of data professionals that we want to examine

# %%
jobs = jobs[jobs['Title'].isin(og_titles)]
print(jobs.shape)
jobs.head()
# Out:
# (438, 9)
#                                    Title    Location           Company  \
# 0     CUSTOMS ADVISOR DATA ANALIST BREDA       Breda               DHL
# 1  Specialist Business Intelligence (BI)   Rotterdam            Milgro
# 2          Business Intelligence Analist  Nieuwegein      Fysioholland
# 4                  Data analist parttime   Amsterdam           Work-on
# 7                           Data Analist     Utrecht  Visser van Baars
#
#                       Salary          Since  Description        Company Url  \
# 0  €2.900 - €3.500 per maand  Net geplaatst          NaN           /cmp/DHL
# 1                        NaN  Net geplaatst          NaN        /cmp/Milgro
# 2                        NaN  Net geplaatst          NaN  /cmp/Fysioholland
# 4          €11 - €13 per uur  Net geplaatst          NaN      /cmp/Work--on
# 7  €4.000 - €5.200 per maand  Net geplaatst          NaN                NaN
#
#                        Industry     Company size
# 0    Transport en vrachtvervoer  Meer dan 10.000
# 1                           NaN              NaN
# 2                           NaN              NaN
# 4  Human resources en personeel        11 tot 50
# 7                           NaN              NaN

# %%
# Group data into categories

categories =  ["Data Engineer","Data Scientist", "Data Analyst", "Business Intelligence Dev/Con", "Business Analyst", "Artificial Intelligence", "Machine Learning"]
    
grouped_titles = [] 

for title in jobs['Title']:
    da = re.search(r'\bdata*[\w]+\b.*\banal[yi]st', title.lower())
    ds = re.search(r'data[- ]scien', title.lower())    
    de = re.search(r'\bdata*[\w]+\b.*\bengineer*[\w]+\b.*?$', title.lower())
    ba = re.search(r'business[- \w]+anal|anal[yi]st', title.lower())
    bi = re.search(r'business[- ]intelli|\bbi\b.', title.lower())
    ml = re.search(r'machine learning[- ]engineer', title.lower())
    ai = re.search(r'artiial intelligence[- ]engi', title.lower())
    tr = re.search(r'translat', title.lower())
    cs = re.search(r'consultant', title.lower())
    if da:
        title = "Data Analyst"
    elif ds:
        title = "Data Scientist"
    elif de:
        title = "Data Engineer"
    elif ba:
        title = "Business Analyst"
    elif bi:
        title = "Business Intelligence Consultant/Engineer"
    elif ml:
        title = "Data Engineer"
    elif ai:
        title = "Data Engineer"
    elif tr:
        title = "Translator"
    elif cs:
        title = "Analytics Consultant"
    else:
        title = "Other"
    
    grouped_titles.append(title)

# %%
# Assign grouped titles to the dataframe
jobs['Title Grouped'] = grouped_titles

# %%
# Confirm there aren't any specific one's that are miscategorized as 'Other'
sorted(list(jobs['Title'][jobs['Title Grouped']=='Other']))
# Out:
# ['(Lead) engineer installatietechniek (E en/of W) datacenters',
#  'Administratief Medewerker Databeheer & Kwaliteit | Punten en...',
#  'Advisor Data & Technology - Assurance',
#  'Big Data Solution Architect',
#  'Big Data Specialist bij het Spaarne Gasthuis',
#  'BusDev/Sales Manager -SAAS-DATA-Germany-Rotterdam-€50K-€80K+...',
#  'Content Marketeer - GoDataDriven',
#  'Data Analytics Manager at Customer Support',
#  'Data Management Professional (m/f)',
#  'Data Migration specialist (Interim)',
#  'Data Partnerships & Outreach Manager, Climate Watch',
#  'Data Specialist',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Steward (Gegevensspecialist Customer Intelligence)',
#  'Data Visualisatie Expert',
#  'Data Visualization expert',
#  'Data custodian',
#  'Data custodian',
#  'Database Marketeer',
#  'Database Marketeer',
#  'Databasebeheerder',
#  'Datalake/Hadoop Beheerder',
#  'Dataplatform / EDW Beheerder',
#  'DevOps Engineer - Application Manager Self Service en Data S...',
#  'DevOps Engineer - Data Management Developer',
#  'DevOps Engineer Data',
#  'Docent Software Engineering & Big data',
#  'Electrical Engineer - Data Centre - Amsterdam',
#  'Engineering Manager - Distributed Data Systems',
#  'Financial Reporting Data Expert',
#  'Fullstack Java Engineer - Data platform for sports! - 55K',
#  'HBO/WO Stage data analyse bij een innovatief zorgbedrijf',
#  'Head of Data Management',
#  'Information & Data Architect(e) Clearing',
#  'Interim Professional Data & Procesanalyse',
#  'Junior dataspecialist',
#  "Junior dataspecialist 'Panel en survey onderzoek'",
#  'MECHANICAL ENGINEER DATA CENTRES (MCF)',
#  'Manager Data Analytics',
#  'Manager Team Databeheer',
#  'Marketing Data Specialist',
#  'Master Data Specialist',
#  'Medewerker data & analytics',
#  'Medewerker datamanagement en kwaliteit',
#  'PhD Position Deep Learning from Unlabelled Sensor Data in La...',
#  'PhD Position New Machine Learning Strategies for Data Scarce...',
#  'PhD position on Learning Analytics and Educational Data Mini...',
#  'Postdoc Data Platforms and Business Models',
#  'Postdoc Humanizing Acoustic Data for Wellbeing',
#  'Product Owner Data & Analyse',
#  'Product Owner Data & Analyse',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Product Owner Dataservices',
#  'Senior Artificial Intelligence Engineer',
#  'Senior Data Intelligence Specialist',
#  'Senior Lead Data Analytics',
#  'Software Engineer – Dataplatform',
#  'Solution Architect (C#, .NET, Azure, Data driven)',
#  'Tech & Data Manager',
#  'Tenure Track position Data Driven Modelling in Computational...',
#  'Traineeship Data',
#  'Traineeship data specialist overheid',
#  'Traineeship data specialist overheid',
#  'senior engineer Big Data System']

# %% [markdown]
# ### Industry check-up

# %%
jobs.Industry.unique()
# Out:
# array(['Transport en vrachtvervoer', nan, 'Human resources en personeel',
#        'Internet en software', 'Banken en financiële dienstverlening',
#        'Detailhandel', 'Energie en nutsbedrijven', 'Overheid',
#        'Voedingsmiddelen en dranken',
#        'Consultancy en zakelijke dienstverlening', 'Onderwijs en scholen',
#        'OverheidConsultancy en zakelijke dienstverlening',
#        'Restaurants, reizen en vrije tijd', 'Media, nieuws en uitgeverij',
#        'Gezondheidszorg', 'Computers en elektronica', 'Farmaceutica',
#        'Verzekering', 'Autosector', 'Maakindustrie',
#        'Landbouw en mijnbouw', 'Telecommunicatie',
#        'Consumentengoederen en dienstverlening', 'Onroerend goed'],
#       dtype=object)

# %%
jobs[jobs['Industry'].isnull()].groupby('Company').count().sort_values(by='Title', ascending=False)
# Out:
#                          Title  Location  Salary  Since  Description  \
# Company
# MagnaVersum                  9         9       0      9            0
# Yacht                        7         7       0      7            0
# Darwin Recruitment           6         6       5      6            0
# My Jewellery                 4         4       0      4            0
# Digital Decisions            4         4       0      4            0
# ...                        ...       ...     ...    ...          ...
# Java Professionals           1         1       0      1            0
# Julius Clinical              1         1       0      1            0
# KLG Europe - Venlo B.V.      1         1       0      1            0
# Kentivo                      1         1       0      1            0
# mySendle                     1         1       0      1            0
#
#                          Company Url  Industry  Company size  Title Grouped
# Company
# MagnaVersum                        0         0             0              9
# Yacht                              7         0             0              7
# Darwin Recruitment                 6         0             6              6
# My Jewellery                       0         0             0              4
# Digital Decisions                  0         0             0              4
# ...                              ...       ...           ...            ...
# Java Professionals                 1         0             1              1
# Julius Clinical                    1         0             1              1
# KLG Europe - Venlo B.V.            0         0             0              1
# Kentivo                            0         0             0              1
# mySendle                           0         0             0              1
#
# [182 rows x 9 columns]

# %% [markdown]
# ### Cleaning salary

# %%
min_salary = []
max_salary = []

for sal in jobs['Salary']:
    if type(sal) == str:
        sal = sal.split('-')
        sal_min = re.sub("[^0-9]", "", sal[0])
        if len(sal) == 2:
            sal_max = re.sub("[^0-9]", "", sal[1])
        else:
            sal_max = sal_min
                                               
    else:
        sal_min = 0
        sal_max = 0
    
    min_salary.append(sal_min)
    max_salary.append(sal_max)
    
jobs['Min Salary'] = min_salary
jobs['Max Salary'] = max_salary

jobs.replace(0, np.nan, inplace=True)

jobs['Min Salary'] = jobs['Min Salary'].astype(float)
jobs['Max Salary'] = jobs['Max Salary'].astype(float)

# %%
jobs.head(60)
# Out:
#                                                  Title              Location  \
# 0                   CUSTOMS ADVISOR DATA ANALIST BREDA                 Breda
# 1                Specialist Business Intelligence (BI)             Rotterdam
# 2                        Business Intelligence Analist            Nieuwegein
# 4                                Data analist parttime             Amsterdam
# 7                                         Data Analist               Utrecht
# 9                     Business Analist – Projectleider               Utrecht
# 12                            Data Visualisatie Expert             Amsterdam
# 33       Senior BI Consultant voor Logistiek Pakketten              Den Haag
# 35                         Data Engineering Consultant               Utrecht
# 41                          Product Owner Dataservices             Amsterdam
# 43             Slimme junior data-analist/ programmeur                Leiden
# 44                    Internship Business Intelligence             Gorinchem
# 45                                 Voice data-engineer            Roosendaal
# 46                                       Data Engineer             Amsterdam
# 47                              System & Data Engineer  Amsterdam Nieuw-West
# 49            Business Analist / Projectleider Utrecht             Nederland
# 51   Data Analyst Sales & Marketing Internship / Gr...             Gorinchem
# 54      Postdoc Humanizing Acoustic Data for Wellbeing                 Delft
# 64                       HBO Meewerkstage Data Science            Amersfoort
# 66                    Content Marketeer - GoDataDriven        Amsterdam Oost
# 73   Chapter Lead Data Engineering - Financial Crim...             Amsterdam
# 75                                       Data Engineer             Hoofddorp
# 77                              Data Scientist 0,8 fte                 Zeist
# 81                        Business Analist Forecasting             Rotterdam
# 82                               Data Science Engineer             Amsterdam
# 84                                 Junior Data Analist             Den Bosch
# 85                                    Business Analist                 Zeist
# 88                                       Data Engineer            Amersfoort
# 90                    Senior Data Scientist Consultant             Amsterdam
# 92           Interim Professional Data & Procesanalyse               Utrecht
# 109                                     Data Scientist             Rotterdam
# 110                                   Business Analist               Alkmaar
# 111                                   Business Analist               Zaandam
# 112        Business Intelligence Consultant Medior rol              Reeuwijk
# 114                                Data analist Vernet     Amsterdam Centrum
# 116                            Business & Data Analyst                 Venlo
# 117                                     Data scientist             Amsterdam
# 119  Data oriented Financial Economic Crime Intelli...             Amsterdam
# 120                            Business & Data Analyst                 Venlo
# 123                                Lead data-scientist              Den Haag
# 125                                       Data Analist                Rhenen
# 126          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 130  Business Intelligence - Data Warehouse Internship     Amsterdam Centrum
# 131                   Business Intelligence Internship             Amsterdam
# 133               Data Engineer voor vergelijkingssite                Zwolle
# 134          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 135                              Senior Data Scientist              Den Haag
# 137                              Senior Data Scientist              Den Haag
# 138          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 141                            Data Engineer (BI-Tech)             Amsterdam
# 143                                   Business Analist             Amsterdam
# 144                            Senior Business Analist              Den Haag
# 148                                   Business analist               Utrecht
# 154                    Business Intelligence Architect             Hilversum
# 158                                 Database Marketeer              Schiedam
# 161            Business Analyst (Home & Personal Care)            Amersfoort
# 165  Tenure Track position Data Driven Modelling in...     Amsterdam Centrum
# 168                                   Business Analyst               Tilburg
# 173                         Product Owner Dataservices             Amsterdam
# 188                                  Database Engineer               Utrecht
#
#                                              Company  \
# 0                                                DHL
# 1                                             Milgro
# 2                                       Fysioholland
# 4                                            Work-on
# 7                                   Visser van Baars
# 9                                             Solveo
# 12                                          Hot ITem
# 33                                            PostNL
# 35                                Visser & Van Baars
# 41                                         BlueTrail
# 43                                             Zight
# 44                                AMF Bakery Systems
# 45                                         Quyx B.V.
# 46                                              Knab
# 47                              DATALOGUE Schweiz AG
# 49                                        OVSoftware
# 51                                AMF Bakery Systems
# 54                                          TU Delft
# 64                                 Morgana Nederland
# 66                     Xccelerated/Binx/GoDataDriven
# 73                                               ING
# 75                                             Macaw
# 77                                   Julius Clinical
# 81                                          Coolblue
# 82                                     TMP Worldwide
# 84                                      YoungCapital
# 85                          Adapt Business Analytics
# 88                                  Weconnect People
# 90                                  Oscar Technology
# 92                                     House of Bèta
# 109                               Woonstad Rotterdam
# 110                                              HVC
# 111                                             ETOS
# 112                                      Tecknoworks
# 114                                           Vernet
# 116                                       KLG Europe
# 117                               Gemeente Amsterdam
# 119                                              ING
# 120                          KLG Europe - Venlo B.V.
# 123  Ministerie van Sociale Zaken en Werkgelegenheid
# 125                                   Page Personnel
# 126                                De Staffing Groep
# 130                                  Creative Clicks
# 131                                       HelloFresh
# 133                               Java Professionals
# 134                                            QWERY
# 135                                            QWERY
# 137                                           LINKIT
# 138                                           LINKIT
# 141                                           Advidi
# 143                                           ilionx
# 144                                          Centric
# 148                                De Staffing Groep
# 154                                     Michael Page
# 158                            DELTA Fiber Nederland
# 161                                          Nouryon
# 165                       Universiteit van Amsterdam
# 168                                   Page Personnel
# 173                                          Qualogy
# 188                                   Walters People
#
#                          Salary              Since  Description  \
# 0     €2.900 - €3.500 per maand      Net geplaatst          NaN
# 1                           NaN      Net geplaatst          NaN
# 2                           NaN      Net geplaatst          NaN
# 4             €11 - €13 per uur      Net geplaatst          NaN
# 7     €4.000 - €5.200 per maand      Net geplaatst          NaN
# 9                           NaN      Net geplaatst          NaN
# 12                          NaN      Net geplaatst          NaN
# 33             €6.201 per maand      Net geplaatst          NaN
# 35    €3.850 - €5.200 per maand      Net geplaatst          NaN
# 41                          NaN      Net geplaatst          NaN
# 43                          NaN  Vandaag geplaatst          NaN
# 44                          NaN  Vandaag geplaatst          NaN
# 45                          NaN  Vandaag geplaatst          NaN
# 46                          NaN  Vandaag geplaatst          NaN
# 47                          NaN  Vandaag geplaatst          NaN
# 49                          NaN  Vandaag geplaatst          NaN
# 51                          NaN  Vandaag geplaatst          NaN
# 54            €32 - €40 per uur  Vandaag geplaatst          NaN
# 64                          NaN  Vandaag geplaatst          NaN
# 66                          NaN  Vandaag geplaatst          NaN
# 73                          NaN  Vandaag geplaatst          NaN
# 75                          NaN      1 dag geleden          NaN
# 77                          NaN      1 dag geleden          NaN
# 81                          NaN    2 dagen geleden          NaN
# 82                          NaN    2 dagen geleden          NaN
# 84                  €17 per uur    2 dagen geleden          NaN
# 85   €50.000 - €75.000 per jaar    2 dagen geleden          NaN
# 88    €3.000 - €4.200 per maand    2 dagen geleden          NaN
# 90   €60.000 - €80.000 per jaar    2 dagen geleden          NaN
# 92                          NaN    2 dagen geleden          NaN
# 109                         NaN    3 dagen geleden          NaN
# 110                         NaN    3 dagen geleden          NaN
# 111            €4.050 per maand    3 dagen geleden          NaN
# 112                         NaN    3 dagen geleden          NaN
# 114                         NaN    3 dagen geleden          NaN
# 116                         NaN    3 dagen geleden          NaN
# 117   €3.881 - €5.464 per maand    3 dagen geleden          NaN
# 119                         NaN    3 dagen geleden          NaN
# 120                         NaN    3 dagen geleden          NaN
# 123                         NaN    3 dagen geleden          NaN
# 125   €3.200 - €4.000 per maand    3 dagen geleden          NaN
# 126                         NaN    3 dagen geleden          NaN
# 130                         NaN    3 dagen geleden          NaN
# 131              €500 per maand    3 dagen geleden          NaN
# 133                         NaN    3 dagen geleden          NaN
# 134                         NaN    3 dagen geleden          NaN
# 135                         NaN    3 dagen geleden          NaN
# 137                         NaN    3 dagen geleden          NaN
# 138                         NaN    3 dagen geleden          NaN
# 141                         NaN    3 dagen geleden          NaN
# 143                         NaN    3 dagen geleden          NaN
# 144                         NaN    3 dagen geleden          NaN
# 148                         NaN    3 dagen geleden          NaN
# 154                         NaN    3 dagen geleden          NaN
# 158                         NaN    3 dagen geleden          NaN
# 161                         NaN    3 dagen geleden          NaN
# 165   €3.637 - €4.978 per maand    3 dagen geleden          NaN
# 168   €2.800 - €3.800 per maand    3 dagen geleden          NaN
# 173                         NaN    3 dagen geleden          NaN
# 188   €2.300 - €3.200 per maand    3 dagen geleden          NaN
#
#                                            Company Url  \
# 0                                             /cmp/DHL
# 1                                          /cmp/Milgro
# 2                                    /cmp/Fysioholland
# 4                                        /cmp/Work--on
# 7                                                  NaN
# 9                                                  NaN
# 12                                       /cmp/Hot-Item
# 33                                         /cmp/Postnl
# 35                                                 NaN
# 41                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                           /cmp/Knab
# 47                                                 NaN
# 49                                     /cmp/Ovsoftware
# 51                                                 NaN
# 54                                       /cmp/Tu-Delft
# 64                                                 NaN
# 66                                                 NaN
# 73                                            /cmp/Ing
# 75                                          /cmp/Macaw
# 77                                /cmp/Julius-Clinical
# 81                                       /cmp/Coolblue
# 82                                                 NaN
# 84                                   /cmp/Youngcapital
# 85                                                 NaN
# 88                                                 NaN
# 90                                                 NaN
# 92                                                 NaN
# 109                            /cmp/Woonstad-Rotterdam
# 110                                           /cmp/Hvc
# 111                                          /cmp/Etos
# 112                                                NaN
# 114                                                NaN
# 116                                    /cmp/Klg-Europe
# 117                            /cmp/Gemeente-Amsterdam
# 119                                           /cmp/Ing
# 120                                                NaN
# 123  /cmp/Ministerie-Van-Sociale-Zaken-En-Werkgeleg...
# 125                                /cmp/Page-Personnel
# 126                             /cmp/De-Staffing-Groep
# 130                                                NaN
# 131                                    /cmp/Hellofresh
# 133                            /cmp/Java-Professionals
# 134                                                NaN
# 135                                                NaN
# 137                                        /cmp/Linkit
# 138                                        /cmp/Linkit
# 141                                                NaN
# 143                                        /cmp/Ilionx
# 144                                       /cmp/Centric
# 148                             /cmp/De-Staffing-Groep
# 154                                  /cmp/Michael-Page
# 158                                                NaN
# 161                                                NaN
# 165                    /cmp/Universiteit-Van-Amsterdam
# 168                                /cmp/Page-Personnel
# 173                                       /cmp/Qualogy
# 188                                /cmp/Walters-People
#
#                                      Industry      Company size  \
# 0                  Transport en vrachtvervoer   Meer dan 10.000
# 1                                         NaN               NaN
# 2                                         NaN               NaN
# 4                Human resources en personeel         11 tot 50
# 7                                         NaN               NaN
# 9                                         NaN               NaN
# 12                                        NaN        51 tot 200
# 33                 Transport en vrachtvervoer   Meer dan 10.000
# 35                                        NaN               NaN
# 41                                        NaN               NaN
# 43                                        NaN               NaN
# 44                                        NaN               NaN
# 45                                        NaN               NaN
# 46                                        NaN        51 tot 200
# 47                                        NaN               NaN
# 49                       Internet en software        51 tot 200
# 51                                        NaN               NaN
# 54                                        NaN               NaN
# 64                                        NaN               NaN
# 66                                        NaN               NaN
# 73       Banken en financiële dienstverlening   Meer dan 10.000
# 75                                        NaN       201 tot 500
# 77                                        NaN        51 tot 200
# 81                               Detailhandel   1.001 tot 5.000
# 82                                        NaN               NaN
# 84               Human resources en personeel   1.001 tot 5.000
# 85                                        NaN               NaN
# 88                                        NaN               NaN
# 90                                        NaN               NaN
# 92                                        NaN               NaN
# 109                                       NaN               NaN
# 110                  Energie en nutsbedrijven   1.001 tot 5.000
# 111                              Detailhandel  5.001 tot 10.000
# 112                                       NaN               NaN
# 114                                       NaN               NaN
# 116                Transport en vrachtvervoer               NaN
# 117                                  Overheid               NaN
# 119      Banken en financiële dienstverlening   Meer dan 10.000
# 120                                       NaN               NaN
# 123                                       NaN               NaN
# 125              Human resources en personeel  5.001 tot 10.000
# 126                                       NaN               NaN
# 130                                       NaN               NaN
# 131               Voedingsmiddelen en dranken   1.001 tot 5.000
# 133                                       NaN          2 tot 10
# 134                                       NaN               NaN
# 135                                       NaN               NaN
# 137  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 138  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 141                                       NaN               NaN
# 143                      Internet en software     501 tot 1.000
# 144                      Internet en software   1.001 tot 5.000
# 148                                       NaN               NaN
# 154              Human resources en personeel  5.001 tot 10.000
# 158                                       NaN               NaN
# 161                                       NaN               NaN
# 165                      Onderwijs en scholen   1.001 tot 5.000
# 168              Human resources en personeel  5.001 tot 10.000
# 173                      Internet en software       201 tot 500
# 188              Human resources en personeel        51 tot 200
#
#                                  Title Grouped  Min Salary  Max Salary
# 0                                 Data Analyst      2900.0      3500.0
# 1    Business Intelligence Consultant/Engineer         NaN         NaN
# 2                             Business Analyst         NaN         NaN
# 4                                 Data Analyst        11.0        13.0
# 7                                 Data Analyst      4000.0      5200.0
# 9                             Business Analyst         NaN         NaN
# 12                                       Other         NaN         NaN
# 33   Business Intelligence Consultant/Engineer      6201.0      6201.0
# 35                               Data Engineer      3850.0      5200.0
# 41                                       Other         NaN         NaN
# 43                                Data Analyst         NaN         NaN
# 44   Business Intelligence Consultant/Engineer         NaN         NaN
# 45                               Data Engineer         NaN         NaN
# 46                               Data Engineer         NaN         NaN
# 47                               Data Engineer         NaN         NaN
# 49                            Business Analyst         NaN         NaN
# 51                                Data Analyst         NaN         NaN
# 54                                       Other        32.0        40.0
# 64                              Data Scientist         NaN         NaN
# 66                                       Other         NaN         NaN
# 73                               Data Engineer         NaN         NaN
# 75                               Data Engineer         NaN         NaN
# 77                              Data Scientist         NaN         NaN
# 81                            Business Analyst         NaN         NaN
# 82                              Data Scientist         NaN         NaN
# 84                                Data Analyst        17.0        17.0
# 85                            Business Analyst     50000.0     75000.0
# 88                               Data Engineer      3000.0      4200.0
# 90                              Data Scientist     60000.0     80000.0
# 92                                       Other         NaN         NaN
# 109                             Data Scientist         NaN         NaN
# 110                           Business Analyst         NaN         NaN
# 111                           Business Analyst      4050.0      4050.0
# 112  Business Intelligence Consultant/Engineer         NaN         NaN
# 114                               Data Analyst         NaN         NaN
# 116                               Data Analyst         NaN         NaN
# 117                             Data Scientist      3881.0      5464.0
# 119                               Data Analyst         NaN         NaN
# 120                               Data Analyst         NaN         NaN
# 123                             Data Scientist         NaN         NaN
# 125                               Data Analyst      3200.0      4000.0
# 126                             Data Scientist         NaN         NaN
# 130  Business Intelligence Consultant/Engineer         NaN         NaN
# 131  Business Intelligence Consultant/Engineer       500.0       500.0
# 133                              Data Engineer         NaN         NaN
# 134                             Data Scientist         NaN         NaN
# 135                             Data Scientist         NaN         NaN
# 137                             Data Scientist         NaN         NaN
# 138                             Data Scientist         NaN         NaN
# 141                              Data Engineer         NaN         NaN
# 143                           Business Analyst         NaN         NaN
# 144                           Business Analyst         NaN         NaN
# 148                           Business Analyst         NaN         NaN
# 154  Business Intelligence Consultant/Engineer         NaN         NaN
# 158                                      Other         NaN         NaN
# 161                           Business Analyst         NaN         NaN
# 165                                      Other      3637.0      4978.0
# 168                           Business Analyst      2800.0      3800.0
# 173                                      Other         NaN         NaN
# 188                              Data Engineer      2300.0      3200.0

# %%
jobs.dtypes
# Out:
# Title             object
# Location          object
# Company           object
# Salary            object
# Since             object
# Description      float64
# Company Url       object
# Industry          object
# Company size      object
# Title Grouped     object
# Min Salary       float64
# Max Salary       float64
# dtype: object

# %%
def sal_type(x):
    try:
        if re.search('maand', x):
            saltype = 'Monthly'
        elif re.search('jaar', x):
            saltype = 'Annual'
        elif re.search('uur', x):
            saltype = 'Hourly'
        elif re.search('week', x):
            saltype='Weekly'
        return saltype
    except:
        saltype = 'Not Specified'
 
        return saltype

# %%
jobs['Salary Type'] = jobs['Salary'].apply(lambda x: sal_type(x))

# %%
jobs['Salary Type'].value_counts()
# Out:
# Not Specified    304
# Monthly          104
# Annual            20
# Hourly             8
# Weekly             2
# Name: Salary Type, dtype: int64

# %%
def norm_salary(x):
    salary_min = 0
    salary_max = 0
    if x['Salary Type'] == 'Annual':
        salary_min = x['Min Salary']/12
        salary_max = x['Max Salary']/12
    elif x['Salary Type'] == 'Hourly':
        salary_min = x['Min Salary']*160
        salary_max = x['Min Salary']*160
    elif x['Salary Type'] == 'Monthly':
        salary_min = x['Min Salary']
        salary_max = x['Max Salary']
    elif x['Salary Type'] == 'Weekly':
        salary_min = x['Min Salary']*4
        salary_max = x['Min Salary']*4
    return salary_min, salary_max

# %%
jobs['Normalized Sal Min'] = jobs.apply(lambda x: norm_salary(x)[0], axis=1)
jobs['Normalized Sal Max'] = jobs.apply(lambda x: norm_salary(x)[1], axis=1)
jobs['Normalized Sal Avg'] = (jobs['Normalized Sal Min']+jobs['Normalized Sal Max'])/2

# %% [markdown]
# #### Cleaning Days since posted

# %%
jobs.Since.value_counts()
# Out:
# Meer dan 30 dagen geleden    78
# 4 dagen geleden              40
# 3 dagen geleden              33
# 13 dagen geleden             27
# 5 dagen geleden              25
# 10 dagen geleden             25
# 11 dagen geleden             24
# 12 dagen geleden             21
# 6 dagen geleden              19
# 14 dagen geleden             18
# 17 dagen geleden             18
# 7 dagen geleden              17
# 19 dagen geleden             16
# 20 dagen geleden             13
# Vandaag geplaatst            11
# 18 dagen geleden             11
# Net geplaatst                10
# 2 dagen geleden               7
# 24 dagen geleden              5
# 9 dagen geleden               4
# 21 dagen geleden              3
# 26 dagen geleden              3
# 27 dagen geleden              2
# 1 dag geleden                 2
# 25 dagen geleden              1
# 28 dagen geleden              1
# 8 dagen geleden               1
# 16 dagen geleden              1
# 23 dagen geleden              1
# 15 dagen geleden              1
# Name: Since, dtype: int64

# %%
# Define functions to derive new date fields

def posted_days(x):
    if x in ['Vandaag geplaatst', 'Net geplaatst']:
        x = 0
    else:
        x = re.sub('[^0-9]', "", x)
        if x == '':
            x = np.nan
    return x 

def posted(x):
    if x <= 7:
        y='This week'
    elif x <= 20:
        y= '2 weeks ago'
    elif x < 27:
        y= '3 weeks ago'
    else:
        y= 'More than 4 weeks ago'
    return y

def posted_date(x):
    return date.today() - timedelta(days=x)
    

jobs['Posted_days'] = jobs['Since'].apply(lambda x: posted_days(x))
jobs['Posted_days'] = jobs['Posted_days'].astype(float)
jobs['Posted'] = jobs['Posted_days'].apply(lambda x: posted(x))
jobs['Date_posted'] = jobs['Posted_days'].apply(lambda x: posted_date(x))

# %%
jobs.head(60)
# Out:
#                                                  Title              Location  \
# 0                   CUSTOMS ADVISOR DATA ANALIST BREDA                 Breda
# 1                Specialist Business Intelligence (BI)             Rotterdam
# 2                        Business Intelligence Analist            Nieuwegein
# 4                                Data analist parttime             Amsterdam
# 7                                         Data Analist               Utrecht
# 9                     Business Analist – Projectleider               Utrecht
# 12                            Data Visualisatie Expert             Amsterdam
# 33       Senior BI Consultant voor Logistiek Pakketten              Den Haag
# 35                         Data Engineering Consultant               Utrecht
# 41                          Product Owner Dataservices             Amsterdam
# 43             Slimme junior data-analist/ programmeur                Leiden
# 44                    Internship Business Intelligence             Gorinchem
# 45                                 Voice data-engineer            Roosendaal
# 46                                       Data Engineer             Amsterdam
# 47                              System & Data Engineer  Amsterdam Nieuw-West
# 49            Business Analist / Projectleider Utrecht             Nederland
# 51   Data Analyst Sales & Marketing Internship / Gr...             Gorinchem
# 54      Postdoc Humanizing Acoustic Data for Wellbeing                 Delft
# 64                       HBO Meewerkstage Data Science            Amersfoort
# 66                    Content Marketeer - GoDataDriven        Amsterdam Oost
# 73   Chapter Lead Data Engineering - Financial Crim...             Amsterdam
# 75                                       Data Engineer             Hoofddorp
# 77                              Data Scientist 0,8 fte                 Zeist
# 81                        Business Analist Forecasting             Rotterdam
# 82                               Data Science Engineer             Amsterdam
# 84                                 Junior Data Analist             Den Bosch
# 85                                    Business Analist                 Zeist
# 88                                       Data Engineer            Amersfoort
# 90                    Senior Data Scientist Consultant             Amsterdam
# 92           Interim Professional Data & Procesanalyse               Utrecht
# 109                                     Data Scientist             Rotterdam
# 110                                   Business Analist               Alkmaar
# 111                                   Business Analist               Zaandam
# 112        Business Intelligence Consultant Medior rol              Reeuwijk
# 114                                Data analist Vernet     Amsterdam Centrum
# 116                            Business & Data Analyst                 Venlo
# 117                                     Data scientist             Amsterdam
# 119  Data oriented Financial Economic Crime Intelli...             Amsterdam
# 120                            Business & Data Analyst                 Venlo
# 123                                Lead data-scientist              Den Haag
# 125                                       Data Analist                Rhenen
# 126          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 130  Business Intelligence - Data Warehouse Internship     Amsterdam Centrum
# 131                   Business Intelligence Internship             Amsterdam
# 133               Data Engineer voor vergelijkingssite                Zwolle
# 134          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 135                              Senior Data Scientist              Den Haag
# 137                              Senior Data Scientist              Den Haag
# 138          Kwantitatief onderzoeker / Data Scientist               Utrecht
# 141                            Data Engineer (BI-Tech)             Amsterdam
# 143                                   Business Analist             Amsterdam
# 144                            Senior Business Analist              Den Haag
# 148                                   Business analist               Utrecht
# 154                    Business Intelligence Architect             Hilversum
# 158                                 Database Marketeer              Schiedam
# 161            Business Analyst (Home & Personal Care)            Amersfoort
# 165  Tenure Track position Data Driven Modelling in...     Amsterdam Centrum
# 168                                   Business Analyst               Tilburg
# 173                         Product Owner Dataservices             Amsterdam
# 188                                  Database Engineer               Utrecht
#
#                                              Company  \
# 0                                                DHL
# 1                                             Milgro
# 2                                       Fysioholland
# 4                                            Work-on
# 7                                   Visser van Baars
# 9                                             Solveo
# 12                                          Hot ITem
# 33                                            PostNL
# 35                                Visser & Van Baars
# 41                                         BlueTrail
# 43                                             Zight
# 44                                AMF Bakery Systems
# 45                                         Quyx B.V.
# 46                                              Knab
# 47                              DATALOGUE Schweiz AG
# 49                                        OVSoftware
# 51                                AMF Bakery Systems
# 54                                          TU Delft
# 64                                 Morgana Nederland
# 66                     Xccelerated/Binx/GoDataDriven
# 73                                               ING
# 75                                             Macaw
# 77                                   Julius Clinical
# 81                                          Coolblue
# 82                                     TMP Worldwide
# 84                                      YoungCapital
# 85                          Adapt Business Analytics
# 88                                  Weconnect People
# 90                                  Oscar Technology
# 92                                     House of Bèta
# 109                               Woonstad Rotterdam
# 110                                              HVC
# 111                                             ETOS
# 112                                      Tecknoworks
# 114                                           Vernet
# 116                                       KLG Europe
# 117                               Gemeente Amsterdam
# 119                                              ING
# 120                          KLG Europe - Venlo B.V.
# 123  Ministerie van Sociale Zaken en Werkgelegenheid
# 125                                   Page Personnel
# 126                                De Staffing Groep
# 130                                  Creative Clicks
# 131                                       HelloFresh
# 133                               Java Professionals
# 134                                            QWERY
# 135                                            QWERY
# 137                                           LINKIT
# 138                                           LINKIT
# 141                                           Advidi
# 143                                           ilionx
# 144                                          Centric
# 148                                De Staffing Groep
# 154                                     Michael Page
# 158                            DELTA Fiber Nederland
# 161                                          Nouryon
# 165                       Universiteit van Amsterdam
# 168                                   Page Personnel
# 173                                          Qualogy
# 188                                   Walters People
#
#                          Salary              Since  Description  \
# 0     €2.900 - €3.500 per maand      Net geplaatst          NaN
# 1                           NaN      Net geplaatst          NaN
# 2                           NaN      Net geplaatst          NaN
# 4             €11 - €13 per uur      Net geplaatst          NaN
# 7     €4.000 - €5.200 per maand      Net geplaatst          NaN
# 9                           NaN      Net geplaatst          NaN
# 12                          NaN      Net geplaatst          NaN
# 33             €6.201 per maand      Net geplaatst          NaN
# 35    €3.850 - €5.200 per maand      Net geplaatst          NaN
# 41                          NaN      Net geplaatst          NaN
# 43                          NaN  Vandaag geplaatst          NaN
# 44                          NaN  Vandaag geplaatst          NaN
# 45                          NaN  Vandaag geplaatst          NaN
# 46                          NaN  Vandaag geplaatst          NaN
# 47                          NaN  Vandaag geplaatst          NaN
# 49                          NaN  Vandaag geplaatst          NaN
# 51                          NaN  Vandaag geplaatst          NaN
# 54            €32 - €40 per uur  Vandaag geplaatst          NaN
# 64                          NaN  Vandaag geplaatst          NaN
# 66                          NaN  Vandaag geplaatst          NaN
# 73                          NaN  Vandaag geplaatst          NaN
# 75                          NaN      1 dag geleden          NaN
# 77                          NaN      1 dag geleden          NaN
# 81                          NaN    2 dagen geleden          NaN
# 82                          NaN    2 dagen geleden          NaN
# 84                  €17 per uur    2 dagen geleden          NaN
# 85   €50.000 - €75.000 per jaar    2 dagen geleden          NaN
# 88    €3.000 - €4.200 per maand    2 dagen geleden          NaN
# 90   €60.000 - €80.000 per jaar    2 dagen geleden          NaN
# 92                          NaN    2 dagen geleden          NaN
# 109                         NaN    3 dagen geleden          NaN
# 110                         NaN    3 dagen geleden          NaN
# 111            €4.050 per maand    3 dagen geleden          NaN
# 112                         NaN    3 dagen geleden          NaN
# 114                         NaN    3 dagen geleden          NaN
# 116                         NaN    3 dagen geleden          NaN
# 117   €3.881 - €5.464 per maand    3 dagen geleden          NaN
# 119                         NaN    3 dagen geleden          NaN
# 120                         NaN    3 dagen geleden          NaN
# 123                         NaN    3 dagen geleden          NaN
# 125   €3.200 - €4.000 per maand    3 dagen geleden          NaN
# 126                         NaN    3 dagen geleden          NaN
# 130                         NaN    3 dagen geleden          NaN
# 131              €500 per maand    3 dagen geleden          NaN
# 133                         NaN    3 dagen geleden          NaN
# 134                         NaN    3 dagen geleden          NaN
# 135                         NaN    3 dagen geleden          NaN
# 137                         NaN    3 dagen geleden          NaN
# 138                         NaN    3 dagen geleden          NaN
# 141                         NaN    3 dagen geleden          NaN
# 143                         NaN    3 dagen geleden          NaN
# 144                         NaN    3 dagen geleden          NaN
# 148                         NaN    3 dagen geleden          NaN
# 154                         NaN    3 dagen geleden          NaN
# 158                         NaN    3 dagen geleden          NaN
# 161                         NaN    3 dagen geleden          NaN
# 165   €3.637 - €4.978 per maand    3 dagen geleden          NaN
# 168   €2.800 - €3.800 per maand    3 dagen geleden          NaN
# 173                         NaN    3 dagen geleden          NaN
# 188   €2.300 - €3.200 per maand    3 dagen geleden          NaN
#
#                                            Company Url  \
# 0                                             /cmp/DHL
# 1                                          /cmp/Milgro
# 2                                    /cmp/Fysioholland
# 4                                        /cmp/Work--on
# 7                                                  NaN
# 9                                                  NaN
# 12                                       /cmp/Hot-Item
# 33                                         /cmp/Postnl
# 35                                                 NaN
# 41                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                           /cmp/Knab
# 47                                                 NaN
# 49                                     /cmp/Ovsoftware
# 51                                                 NaN
# 54                                       /cmp/Tu-Delft
# 64                                                 NaN
# 66                                                 NaN
# 73                                            /cmp/Ing
# 75                                          /cmp/Macaw
# 77                                /cmp/Julius-Clinical
# 81                                       /cmp/Coolblue
# 82                                                 NaN
# 84                                   /cmp/Youngcapital
# 85                                                 NaN
# 88                                                 NaN
# 90                                                 NaN
# 92                                                 NaN
# 109                            /cmp/Woonstad-Rotterdam
# 110                                           /cmp/Hvc
# 111                                          /cmp/Etos
# 112                                                NaN
# 114                                                NaN
# 116                                    /cmp/Klg-Europe
# 117                            /cmp/Gemeente-Amsterdam
# 119                                           /cmp/Ing
# 120                                                NaN
# 123  /cmp/Ministerie-Van-Sociale-Zaken-En-Werkgeleg...
# 125                                /cmp/Page-Personnel
# 126                             /cmp/De-Staffing-Groep
# 130                                                NaN
# 131                                    /cmp/Hellofresh
# 133                            /cmp/Java-Professionals
# 134                                                NaN
# 135                                                NaN
# 137                                        /cmp/Linkit
# 138                                        /cmp/Linkit
# 141                                                NaN
# 143                                        /cmp/Ilionx
# 144                                       /cmp/Centric
# 148                             /cmp/De-Staffing-Groep
# 154                                  /cmp/Michael-Page
# 158                                                NaN
# 161                                                NaN
# 165                    /cmp/Universiteit-Van-Amsterdam
# 168                                /cmp/Page-Personnel
# 173                                       /cmp/Qualogy
# 188                                /cmp/Walters-People
#
#                                      Industry      Company size  \
# 0                  Transport en vrachtvervoer   Meer dan 10.000
# 1                                         NaN               NaN
# 2                                         NaN               NaN
# 4                Human resources en personeel         11 tot 50
# 7                                         NaN               NaN
# 9                                         NaN               NaN
# 12                                        NaN        51 tot 200
# 33                 Transport en vrachtvervoer   Meer dan 10.000
# 35                                        NaN               NaN
# 41                                        NaN               NaN
# 43                                        NaN               NaN
# 44                                        NaN               NaN
# 45                                        NaN               NaN
# 46                                        NaN        51 tot 200
# 47                                        NaN               NaN
# 49                       Internet en software        51 tot 200
# 51                                        NaN               NaN
# 54                                        NaN               NaN
# 64                                        NaN               NaN
# 66                                        NaN               NaN
# 73       Banken en financiële dienstverlening   Meer dan 10.000
# 75                                        NaN       201 tot 500
# 77                                        NaN        51 tot 200
# 81                               Detailhandel   1.001 tot 5.000
# 82                                        NaN               NaN
# 84               Human resources en personeel   1.001 tot 5.000
# 85                                        NaN               NaN
# 88                                        NaN               NaN
# 90                                        NaN               NaN
# 92                                        NaN               NaN
# 109                                       NaN               NaN
# 110                  Energie en nutsbedrijven   1.001 tot 5.000
# 111                              Detailhandel  5.001 tot 10.000
# 112                                       NaN               NaN
# 114                                       NaN               NaN
# 116                Transport en vrachtvervoer               NaN
# 117                                  Overheid               NaN
# 119      Banken en financiële dienstverlening   Meer dan 10.000
# 120                                       NaN               NaN
# 123                                       NaN               NaN
# 125              Human resources en personeel  5.001 tot 10.000
# 126                                       NaN               NaN
# 130                                       NaN               NaN
# 131               Voedingsmiddelen en dranken   1.001 tot 5.000
# 133                                       NaN          2 tot 10
# 134                                       NaN               NaN
# 135                                       NaN               NaN
# 137  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 138  Consultancy en zakelijke dienstverlening     501 tot 1.000
# 141                                       NaN               NaN
# 143                      Internet en software     501 tot 1.000
# 144                      Internet en software   1.001 tot 5.000
# 148                                       NaN               NaN
# 154              Human resources en personeel  5.001 tot 10.000
# 158                                       NaN               NaN
# 161                                       NaN               NaN
# 165                      Onderwijs en scholen   1.001 tot 5.000
# 168              Human resources en personeel  5.001 tot 10.000
# 173                      Internet en software       201 tot 500
# 188              Human resources en personeel        51 tot 200
#
#                                  Title Grouped  Min Salary  Max Salary  \
# 0                                 Data Analyst      2900.0      3500.0
# 1    Business Intelligence Consultant/Engineer         NaN         NaN
# 2                             Business Analyst         NaN         NaN
# 4                                 Data Analyst        11.0        13.0
# 7                                 Data Analyst      4000.0      5200.0
# 9                             Business Analyst         NaN         NaN
# 12                                       Other         NaN         NaN
# 33   Business Intelligence Consultant/Engineer      6201.0      6201.0
# 35                               Data Engineer      3850.0      5200.0
# 41                                       Other         NaN         NaN
# 43                                Data Analyst         NaN         NaN
# 44   Business Intelligence Consultant/Engineer         NaN         NaN
# 45                               Data Engineer         NaN         NaN
# 46                               Data Engineer         NaN         NaN
# 47                               Data Engineer         NaN         NaN
# 49                            Business Analyst         NaN         NaN
# 51                                Data Analyst         NaN         NaN
# 54                                       Other        32.0        40.0
# 64                              Data Scientist         NaN         NaN
# 66                                       Other         NaN         NaN
# 73                               Data Engineer         NaN         NaN
# 75                               Data Engineer         NaN         NaN
# 77                              Data Scientist         NaN         NaN
# 81                            Business Analyst         NaN         NaN
# 82                              Data Scientist         NaN         NaN
# 84                                Data Analyst        17.0        17.0
# 85                            Business Analyst     50000.0     75000.0
# 88                               Data Engineer      3000.0      4200.0
# 90                              Data Scientist     60000.0     80000.0
# 92                                       Other         NaN         NaN
# 109                             Data Scientist         NaN         NaN
# 110                           Business Analyst         NaN         NaN
# 111                           Business Analyst      4050.0      4050.0
# 112  Business Intelligence Consultant/Engineer         NaN         NaN
# 114                               Data Analyst         NaN         NaN
# 116                               Data Analyst         NaN         NaN
# 117                             Data Scientist      3881.0      5464.0
# 119                               Data Analyst         NaN         NaN
# 120                               Data Analyst         NaN         NaN
# 123                             Data Scientist         NaN         NaN
# 125                               Data Analyst      3200.0      4000.0
# 126                             Data Scientist         NaN         NaN
# 130  Business Intelligence Consultant/Engineer         NaN         NaN
# 131  Business Intelligence Consultant/Engineer       500.0       500.0
# 133                              Data Engineer         NaN         NaN
# 134                             Data Scientist         NaN         NaN
# 135                             Data Scientist         NaN         NaN
# 137                             Data Scientist         NaN         NaN
# 138                             Data Scientist         NaN         NaN
# 141                              Data Engineer         NaN         NaN
# 143                           Business Analyst         NaN         NaN
# 144                           Business Analyst         NaN         NaN
# 148                           Business Analyst         NaN         NaN
# 154  Business Intelligence Consultant/Engineer         NaN         NaN
# 158                                      Other         NaN         NaN
# 161                           Business Analyst         NaN         NaN
# 165                                      Other      3637.0      4978.0
# 168                           Business Analyst      2800.0      3800.0
# 173                                      Other         NaN         NaN
# 188                              Data Engineer      2300.0      3200.0
#
#        Salary Type  Normalized Sal Min  Normalized Sal Max  \
# 0          Monthly         2900.000000         3500.000000
# 1    Not Specified            0.000000            0.000000
# 2    Not Specified            0.000000            0.000000
# 4           Hourly         1760.000000         1760.000000
# 7          Monthly         4000.000000         5200.000000
# 9    Not Specified            0.000000            0.000000
# 12   Not Specified            0.000000            0.000000
# 33         Monthly         6201.000000         6201.000000
# 35         Monthly         3850.000000         5200.000000
# 41   Not Specified            0.000000            0.000000
# 43   Not Specified            0.000000            0.000000
# 44   Not Specified            0.000000            0.000000
# 45   Not Specified            0.000000            0.000000
# 46   Not Specified            0.000000            0.000000
# 47   Not Specified            0.000000            0.000000
# 49   Not Specified            0.000000            0.000000
# 51   Not Specified            0.000000            0.000000
# 54          Hourly         5120.000000         5120.000000
# 64   Not Specified            0.000000            0.000000
# 66   Not Specified            0.000000            0.000000
# 73   Not Specified            0.000000            0.000000
# 75   Not Specified            0.000000            0.000000
# 77   Not Specified            0.000000            0.000000
# 81   Not Specified            0.000000            0.000000
# 82   Not Specified            0.000000            0.000000
# 84          Hourly         2720.000000         2720.000000
# 85          Annual         4166.666667         6250.000000
# 88         Monthly         3000.000000         4200.000000
# 90          Annual         5000.000000         6666.666667
# 92   Not Specified            0.000000            0.000000
# 109  Not Specified            0.000000            0.000000
# 110  Not Specified            0.000000            0.000000
# 111        Monthly         4050.000000         4050.000000
# 112  Not Specified            0.000000            0.000000
# 114  Not Specified            0.000000            0.000000
# 116  Not Specified            0.000000            0.000000
# 117        Monthly         3881.000000         5464.000000
# 119  Not Specified            0.000000            0.000000
# 120  Not Specified            0.000000            0.000000
# 123  Not Specified            0.000000            0.000000
# 125        Monthly         3200.000000         4000.000000
# 126  Not Specified            0.000000            0.000000
# 130  Not Specified            0.000000            0.000000
# 131        Monthly          500.000000          500.000000
# 133  Not Specified            0.000000            0.000000
# 134  Not Specified            0.000000            0.000000
# 135  Not Specified            0.000000            0.000000
# 137  Not Specified            0.000000            0.000000
# 138  Not Specified            0.000000            0.000000
# 141  Not Specified            0.000000            0.000000
# 143  Not Specified            0.000000            0.000000
# 144  Not Specified            0.000000            0.000000
# 148  Not Specified            0.000000            0.000000
# 154  Not Specified            0.000000            0.000000
# 158  Not Specified            0.000000            0.000000
# 161  Not Specified            0.000000            0.000000
# 165        Monthly         3637.000000         4978.000000
# 168        Monthly         2800.000000         3800.000000
# 173  Not Specified            0.000000            0.000000
# 188        Monthly         2300.000000         3200.000000
#
#      Normalized Sal Avg  Posted_days     Posted Date_posted
# 0           3200.000000          0.0  This week  2020-06-29
# 1              0.000000          0.0  This week  2020-06-29
# 2              0.000000          0.0  This week  2020-06-29
# 4           1760.000000          0.0  This week  2020-06-29
# 7           4600.000000          0.0  This week  2020-06-29
# 9              0.000000          0.0  This week  2020-06-29
# 12             0.000000          0.0  This week  2020-06-29
# 33          6201.000000          0.0  This week  2020-06-29
# 35          4525.000000          0.0  This week  2020-06-29
# 41             0.000000          0.0  This week  2020-06-29
# 43             0.000000          0.0  This week  2020-06-29
# 44             0.000000          0.0  This week  2020-06-29
# 45             0.000000          0.0  This week  2020-06-29
# 46             0.000000          0.0  This week  2020-06-29
# 47             0.000000          0.0  This week  2020-06-29
# 49             0.000000          0.0  This week  2020-06-29
# 51             0.000000          0.0  This week  2020-06-29
# 54          5120.000000          0.0  This week  2020-06-29
# 64             0.000000          0.0  This week  2020-06-29
# 66             0.000000          0.0  This week  2020-06-29
# 73             0.000000          0.0  This week  2020-06-29
# 75             0.000000          1.0  This week  2020-06-28
# 77             0.000000          1.0  This week  2020-06-28
# 81             0.000000          2.0  This week  2020-06-27
# 82             0.000000          2.0  This week  2020-06-27
# 84          2720.000000          2.0  This week  2020-06-27
# 85          5208.333333          2.0  This week  2020-06-27
# 88          3600.000000          2.0  This week  2020-06-27
# 90          5833.333333          2.0  This week  2020-06-27
# 92             0.000000          2.0  This week  2020-06-27
# 109            0.000000          3.0  This week  2020-06-26
# 110            0.000000          3.0  This week  2020-06-26
# 111         4050.000000          3.0  This week  2020-06-26
# 112            0.000000          3.0  This week  2020-06-26
# 114            0.000000          3.0  This week  2020-06-26
# 116            0.000000          3.0  This week  2020-06-26
# 117         4672.500000          3.0  This week  2020-06-26
# 119            0.000000          3.0  This week  2020-06-26
# 120            0.000000          3.0  This week  2020-06-26
# 123            0.000000          3.0  This week  2020-06-26
# 125         3600.000000          3.0  This week  2020-06-26
# 126            0.000000          3.0  This week  2020-06-26
# 130            0.000000          3.0  This week  2020-06-26
# 131          500.000000          3.0  This week  2020-06-26
# 133            0.000000          3.0  This week  2020-06-26
# 134            0.000000          3.0  This week  2020-06-26
# 135            0.000000          3.0  This week  2020-06-26
# 137            0.000000          3.0  This week  2020-06-26
# 138            0.000000          3.0  This week  2020-06-26
# 141            0.000000          3.0  This week  2020-06-26
# 143            0.000000          3.0  This week  2020-06-26
# 144            0.000000          3.0  This week  2020-06-26
# 148            0.000000          3.0  This week  2020-06-26
# 154            0.000000          3.0  This week  2020-06-26
# 158            0.000000          3.0  This week  2020-06-26
# 161            0.000000          3.0  This week  2020-06-26
# 165         4307.500000          3.0  This week  2020-06-26
# 168         3300.000000          3.0  This week  2020-06-26
# 173            0.000000          3.0  This week  2020-06-26
# 188         2750.000000          3.0  This week  2020-06-26

# %% [markdown]
# ## Cleaning Locations

# %%
sorted_list = sorted(jobs['Location'].unique())
print(sorted_list)
# Out:
# ['Alkmaar', 'Amersfoort', 'Amsterdam', 'Amsterdam Centrum', 'Amsterdam Nieuw-West', 'Amsterdam Oost', 'Amsterdam Westpoort', 'Amsterdam Zuid', 'Apeldoorn', 'Arnhem', 'Baarn', 'Breda', 'Bronkhorst', 'Capelle aan den IJssel', 'Culemborg', 'De Wijert & Helpman-West', 'Delft', 'Den Bosch', 'Den Haag', 'Diemen', 'Doesburg', 'Dordrecht', 'Driebergen', 'Driebergen-Rijsenburg', 'Duiven', 'Eindhoven', 'Fijnaart', 'Gemeente Hardinxveld-Giessendam', 'Gorinchem', 'Gouda', 'Groningen', 'Heerlen', 'Helmond', 'Hengelo OV', 'Hilversum', 'Hoofddorp', 'Hoogeveen', 'Huizen', 'Leerdam', 'Leeuwarden', 'Leiden', 'Lelystad', 'Leusden', 'Maastricht', 'Naarden', 'Nederland', 'Nieuw-Vennep', 'Nieuwegein', 'Nijmegen', 'Nuenen', 'Nuth', 'Oegstgeest', 'Oirschot', 'Oss', 'Oud-Beijerland', 'Poeldijk', 'Reeuwijk', 'Rhenen', 'Ridderkerk', 'Rijssen', 'Rijswijk', 'Roosendaal', 'Rotterdam', 'Schiedam', 'Schiphol', 'Sloterdijk', 'Tiel', 'Tilburg', 'Twente', 'Utrecht', 'Utrecht Oost', 'Utrecht Zuidwest', 'Veenendaal', 'Veldhoven', 'Venlo', 'Weert', 'Weesp', 'Werk van thuis', 'Westerbroek', 'Wijchen', 'Wijk bij Duurstede', 'Willemstad Curaçao', 'Woerden', 'Zaandam', 'Zaanstad', 'Zaltbommel', 'Zeeland', 'Zeist', 'Zevenaar', 'Zoetermeer', 'Zutphen', 'Zwolle']

# %%
jobs['Location'].value_counts().sum()
# Out:
# 438

# %%
big_cities = ['amsterdam', 'utrecht', 'den haag', 'rotterdam']

# %%
def city_clean(x):
    x = x.replace('-', ' ')
    for city in big_cities:
        if re.search(city, x.lower()):
            x = x.split(' ')[0]
            if x == 'Den':
                x = 'Den Haag'
    return x

jobs['Location Grouped'] = jobs['Location'].apply(lambda x: city_clean(x))

# %%
jobs.Location.value_counts()
# Out:
# Amsterdam         88
# Utrecht           55
# Rotterdam         28
# Den Haag          23
# Amersfoort        15
#                   ..
# Hoogeveen          1
# Naarden            1
# Zevenaar           1
# Roosendaal         1
# Amsterdam Oost     1
# Name: Location, Length: 92, dtype: int64

# %% [markdown]
# Final check of the data

# %%
jobs.head()
# Out:
#                                    Title    Location           Company  \
# 0     CUSTOMS ADVISOR DATA ANALIST BREDA       Breda               DHL
# 1  Specialist Business Intelligence (BI)   Rotterdam            Milgro
# 2          Business Intelligence Analist  Nieuwegein      Fysioholland
# 4                  Data analist parttime   Amsterdam           Work-on
# 7                           Data Analist     Utrecht  Visser van Baars
#
#                       Salary          Since  Description        Company Url  \
# 0  €2.900 - €3.500 per maand  Net geplaatst          NaN           /cmp/DHL
# 1                        NaN  Net geplaatst          NaN        /cmp/Milgro
# 2                        NaN  Net geplaatst          NaN  /cmp/Fysioholland
# 4          €11 - €13 per uur  Net geplaatst          NaN      /cmp/Work--on
# 7  €4.000 - €5.200 per maand  Net geplaatst          NaN                NaN
#
#                        Industry     Company size  \
# 0    Transport en vrachtvervoer  Meer dan 10.000
# 1                           NaN              NaN
# 2                           NaN              NaN
# 4  Human resources en personeel        11 tot 50
# 7                           NaN              NaN
#
#                                Title Grouped  Min Salary  Max Salary  \
# 0                               Data Analyst      2900.0      3500.0
# 1  Business Intelligence Consultant/Engineer         NaN         NaN
# 2                           Business Analyst         NaN         NaN
# 4                               Data Analyst        11.0        13.0
# 7                               Data Analyst      4000.0      5200.0
#
#      Salary Type  Normalized Sal Min  Normalized Sal Max  Normalized Sal Avg  \
# 0        Monthly              2900.0              3500.0              3200.0
# 1  Not Specified                 0.0                 0.0                 0.0
# 2  Not Specified                 0.0                 0.0                 0.0
# 4         Hourly              1760.0              1760.0              1760.0
# 7        Monthly              4000.0              5200.0              4600.0
#
#    Posted_days     Posted Date_posted Location Grouped
# 0          0.0  This week  2020-06-29            Breda
# 1          0.0  This week  2020-06-29        Rotterdam
# 2          0.0  This week  2020-06-29       Nieuwegein
# 4          0.0  This week  2020-06-29        Amsterdam
# 7          0.0  This week  2020-06-29          Utrecht

# %%
jobs.drop(columns={'Description', 'Company Url'}, inplace=True)

# %% [markdown]
# #### Cleaning Industries

# %%
jobs[jobs['Industry'].isnull()].groupby('Company').count().sort_values(by='Title', ascending=False)
# Out:
#                          Title  Location  Salary  Since  Industry  \
# Company
# MagnaVersum                  9         9       0      9         0
# Yacht                        7         7       0      7         0
# Darwin Recruitment           6         6       5      6         0
# My Jewellery                 4         4       0      4         0
# Digital Decisions            4         4       0      4         0
# ...                        ...       ...     ...    ...       ...
# Java Professionals           1         1       0      1         0
# Julius Clinical              1         1       0      1         0
# KLG Europe - Venlo B.V.      1         1       0      1         0
# Kentivo                      1         1       0      1         0
# mySendle                     1         1       0      1         0
#
#                          Company size  Title Grouped  Min Salary  Max Salary  \
# Company
# MagnaVersum                         0              9           0           0
# Yacht                               0              7           0           0
# Darwin Recruitment                  6              6           5           5
# My Jewellery                        0              4           0           0
# Digital Decisions                   0              4           0           0
# ...                               ...            ...         ...         ...
# Java Professionals                  1              1           0           0
# Julius Clinical                     1              1           0           0
# KLG Europe - Venlo B.V.             0              1           0           0
# Kentivo                             0              1           0           0
# mySendle                            0              1           0           0
#
#                          Salary Type  Normalized Sal Min  Normalized Sal Max  \
# Company
# MagnaVersum                        9                   9                   9
# Yacht                              7                   7                   7
# Darwin Recruitment                 6                   6                   6
# My Jewellery                       4                   4                   4
# Digital Decisions                  4                   4                   4
# ...                              ...                 ...                 ...
# Java Professionals                 1                   1                   1
# Julius Clinical                    1                   1                   1
# KLG Europe - Venlo B.V.            1                   1                   1
# Kentivo                            1                   1                   1
# mySendle                           1                   1                   1
#
#                          Normalized Sal Avg  Posted_days  Posted  Date_posted  \
# Company
# MagnaVersum                               9            9       9            9
# Yacht                                     7            7       7            7
# Darwin Recruitment                        6            6       6            6
# My Jewellery                              4            4       4            4
# Digital Decisions                         4            4       4            4
# ...                                     ...          ...     ...          ...
# Java Professionals                        1            1       1            1
# Julius Clinical                           1            1       1            1
# KLG Europe - Venlo B.V.                   1            1       1            1
# Kentivo                                   1            1       1            1
# mySendle                                  1            1       1            1
#
#                          Location Grouped
# Company
# MagnaVersum                             9
# Yacht                                   7
# Darwin Recruitment                      6
# My Jewellery                            4
# Digital Decisions                       4
# ...                                   ...
# Java Professionals                      1
# Julius Clinical                         1
# KLG Europe - Venlo B.V.                 1
# Kentivo                                 1
# mySendle                                1
#
# [182 rows x 17 columns]

# %%
jobs.to_csv('jobs_cleaned_final.csv', index=False)

# %%
# import required libraries to connet to MySQL Database
import pymysql 
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:xxxxx@localhost:3306/data_jobs_nl')

# %%
jobs.to_sql('jobs_last_30', engine, if_exists='replace', index=False)
